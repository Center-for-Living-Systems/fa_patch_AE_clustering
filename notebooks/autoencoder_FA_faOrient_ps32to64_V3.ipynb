# %%
import tensorflow as tf
from utils import actomyosin_data, plot64
from model.autoencoder_64 import AE, VAE, CVAE
from train_utils.autoencoder import AETrain, VAETrain, CVAETrain
import time
import argparse
from datetime import datetime
from packaging import version
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd
import tifffile
import os
import warnings
from itertools import cycle, islice

from skimage.transform import resize
from skimage.io import imsave, imread

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
# Out:
# 2025-01-29 11:58:42.144951: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
# args
ae_type = 'AE'
net_type = 'conv'
latent_dim = 12
num_epochs = 1000
learn_rate = 0.001
train_buf = 12000
batch_size = 800

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorboard
tensorboard.__version__
# Out:
# '2.12.1'

# %%
log_dir = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
# Out:
# 2025-01-29 12:42:39.471665: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2025-01-29 12:42:39.471695: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2025-01-29 12:42:39.471895: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2025-01-29 12:42:39.472070: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1487] CUPTI activity buffer flushed

# %%
data_dir = '/mnt/d/lding/FA/analysis_results/encoder/partitioned_data_rand_flow/annabel_0226_patchsize_64'
patch_size = 64

filenames = [x for x in os.listdir(data_dir) if os.path.isfile(os.path.join(data_dir, x)) and ('.tif' in x)]
filenames.sort()

num_of_samples = min(len(filenames),train_buf)

train_images = np.zeros([num_of_samples, patch_size, patch_size])
train_labels= np.zeros([num_of_samples])

for filename_ind in range(num_of_samples):
    filename = filenames[filename_ind] 
             
    train_img = tifffile.imread(os.path.join(data_dir,filename))
    small_train_img = resize(train_img[16:48,16:48],[64,64])/1
    # small_train_img = small_train_img/small_train_img.max()
    train_images[filename_ind,:,:] = small_train_img
    train_labels[filename_ind] = int(filename[-22:-18]+filename[-17:-13]+filename[-12:-8])


train_images = train_images.reshape(train_images.shape[0], 64, 64, 1).astype('float32')

# %%
print(filename[-22:-18]+filename[-17:-13]+filename[-12:-8])
# Out:
# 109207141160

# %%
filenames[-1]
# Out:
# 'Rock 30min 5_cell1092x0714y1160ps64.tif'

# %%
TRAIN_BUF = train_buf
BATCH_SIZE = batch_size

train_dataset_image = tf.data.Dataset.from_tensor_slices(train_images).batch(BATCH_SIZE)
train_dataset_label = tf.data.Dataset.from_tensor_slices(train_labels).batch(BATCH_SIZE)
train_dataset = tf.data.Dataset.zip((train_dataset_image, train_dataset_label)).shuffle(TRAIN_BUF)

# %%
model = AE(latent_dim, net_type=net_type)
model_ID = 'FA_annabel_'+ae_type+'_ld'+str(latent_dim)+'_nt'+net_type+'_bs'+ str(batch_size)+'_ps32to64'

# %%
optimizer = tf.keras.optimizers.Adam(learn_rate)

for epoch in range(1, num_epochs + 1):
    t = time.time()
    last_loss = 0
    for train_x, _ in train_dataset:
        gradients, loss = AETrain.compute_gradients(model, train_x)
        AETrain.apply_gradients(optimizer, gradients, model.trainable_variables)
        last_loss = loss
    if epoch % 10 == 0:
        print('Epoch {}, Loss: {}, Remaining Time at This Epoch: {:.2f}'.format(
            epoch, last_loss, time.time() - t
        ))

# # Create a basic model instance
# model = create_model()

# # Display the model's architecture
# model.summary()
# Out:
# Epoch 10, Loss: 0.6663604974746704, Remaining Time at This Epoch: 0.36
# Epoch 20, Loss: 0.6078610420227051, Remaining Time at This Epoch: 0.32
# Epoch 30, Loss: 0.49516165256500244, Remaining Time at This Epoch: 0.40
# Epoch 40, Loss: 0.44649383425712585, Remaining Time at This Epoch: 0.37
# Epoch 50, Loss: 0.4924493432044983, Remaining Time at This Epoch: 0.35
# Epoch 60, Loss: 0.49171552062034607, Remaining Time at This Epoch: 0.36
# Epoch 70, Loss: 0.5073115825653076, Remaining Time at This Epoch: 0.38
# Epoch 80, Loss: 0.4497770369052887, Remaining Time at This Epoch: 0.32
# Epoch 90, Loss: 0.47328057885169983, Remaining Time at This Epoch: 0.31
# Epoch 100, Loss: 0.5093534588813782, Remaining Time at This Epoch: 0.34
# Epoch 110, Loss: 0.49074921011924744, Remaining Time at This Epoch: 0.36
# Epoch 120, Loss: 0.460204154253006, Remaining Time at This Epoch: 0.43
# Epoch 130, Loss: 0.4939405918121338, Remaining Time at This Epoch: 0.38
# Epoch 140, Loss: 0.49530482292175293, Remaining Time at This Epoch: 0.29
# Epoch 150, Loss: 0.4808962047100067, Remaining Time at This Epoch: 0.32
# Epoch 160, Loss: 0.5070602297782898, Remaining Time at This Epoch: 0.26
# Epoch 170, Loss: 0.5301904678344727, Remaining Time at This Epoch: 0.26
# Epoch 180, Loss: 0.48053792119026184, Remaining Time at This Epoch: 0.23
# Epoch 190, Loss: 0.46148207783699036, Remaining Time at This Epoch: 0.28
# Epoch 200, Loss: 0.5298168063163757, Remaining Time at This Epoch: 0.27
# Epoch 210, Loss: 0.5067332983016968, Remaining Time at This Epoch: 0.28
# Epoch 220, Loss: 0.4892774224281311, Remaining Time at This Epoch: 0.27
# Epoch 230, Loss: 0.5292518734931946, Remaining Time at This Epoch: 0.25
# Epoch 240, Loss: 0.5076243877410889, Remaining Time at This Epoch: 0.31
# Epoch 250, Loss: 0.48298385739326477, Remaining Time at This Epoch: 0.29
# Epoch 260, Loss: 0.48168036341667175, Remaining Time at This Epoch: 0.26
# Epoch 270, Loss: 0.5344033241271973, Remaining Time at This Epoch: 0.28
# Epoch 280, Loss: 0.485648512840271, Remaining Time at This Epoch: 0.25
# Epoch 290, Loss: 0.48029622435569763, Remaining Time at This Epoch: 0.29
# Epoch 300, Loss: 0.5216827988624573, Remaining Time at This Epoch: 0.27
# Epoch 310, Loss: 0.48176515102386475, Remaining Time at This Epoch: 0.27
# Epoch 320, Loss: 0.5065017938613892, Remaining Time at This Epoch: 0.30
# Epoch 330, Loss: 0.49347442388534546, Remaining Time at This Epoch: 0.29
# Epoch 340, Loss: 0.5212808847427368, Remaining Time at This Epoch: 0.28
# Epoch 350, Loss: 0.5213878154754639, Remaining Time at This Epoch: 0.28
# Epoch 360, Loss: 0.5301004648208618, Remaining Time at This Epoch: 0.27
# Epoch 370, Loss: 0.48632562160491943, Remaining Time at This Epoch: 0.32
# Epoch 380, Loss: 0.48111823201179504, Remaining Time at This Epoch: 0.27
# Epoch 390, Loss: 0.547176718711853, Remaining Time at This Epoch: 0.28
# Epoch 400, Loss: 0.5202878713607788, Remaining Time at This Epoch: 0.26
# Epoch 410, Loss: 0.4790523648262024, Remaining Time at This Epoch: 0.27
# Epoch 420, Loss: 0.5090858340263367, Remaining Time at This Epoch: 0.25
# Epoch 430, Loss: 0.4789547622203827, Remaining Time at This Epoch: 0.28
# Epoch 440, Loss: 0.45430710911750793, Remaining Time at This Epoch: 0.27
# Epoch 450, Loss: 0.4966982901096344, Remaining Time at This Epoch: 0.26
# Epoch 460, Loss: 0.4584086537361145, Remaining Time at This Epoch: 0.24
# Epoch 470, Loss: 0.4899504780769348, Remaining Time at This Epoch: 0.26
# Epoch 480, Loss: 0.480656236410141, Remaining Time at This Epoch: 0.26
# Epoch 490, Loss: 0.4713735282421112, Remaining Time at This Epoch: 0.30
# Epoch 500, Loss: 0.48914244771003723, Remaining Time at This Epoch: 0.27
# Epoch 510, Loss: 0.4987572729587555, Remaining Time at This Epoch: 0.25
# Epoch 520, Loss: 0.4890238642692566, Remaining Time at This Epoch: 0.24
# Epoch 530, Loss: 0.5217918157577515, Remaining Time at This Epoch: 0.28
# Epoch 540, Loss: 0.7549266219139099, Remaining Time at This Epoch: 0.25
# Epoch 550, Loss: 0.46851158142089844, Remaining Time at This Epoch: 0.31
# Epoch 560, Loss: 0.49751707911491394, Remaining Time at This Epoch: 0.27
# Epoch 570, Loss: 0.485047310590744, Remaining Time at This Epoch: 0.26
# Epoch 580, Loss: 0.4927131235599518, Remaining Time at This Epoch: 0.29
# Epoch 590, Loss: 0.47541695833206177, Remaining Time at This Epoch: 0.28
# Epoch 600, Loss: 0.4927384555339813, Remaining Time at This Epoch: 0.27
# Epoch 610, Loss: 0.44867244362831116, Remaining Time at This Epoch: 0.29
# Epoch 620, Loss: 0.4570043087005615, Remaining Time at This Epoch: 0.27
# Epoch 630, Loss: 0.5180637836456299, Remaining Time at This Epoch: 0.28
# Epoch 640, Loss: 0.5045745968818665, Remaining Time at This Epoch: 0.31
# Epoch 650, Loss: 0.5071590542793274, Remaining Time at This Epoch: 0.30
# Epoch 660, Loss: 0.4486777186393738, Remaining Time at This Epoch: 0.27
# Epoch 670, Loss: 0.4984869360923767, Remaining Time at This Epoch: 0.29
# Epoch 680, Loss: 0.5407865047454834, Remaining Time at This Epoch: 0.28
# Epoch 690, Loss: 0.4692007005214691, Remaining Time at This Epoch: 0.31
# Epoch 700, Loss: 0.5125276446342468, Remaining Time at This Epoch: 0.31
# Epoch 710, Loss: 0.5292227268218994, Remaining Time at This Epoch: 0.29
# Epoch 720, Loss: 0.4470912218093872, Remaining Time at This Epoch: 0.24
# Epoch 730, Loss: 0.5014339685440063, Remaining Time at This Epoch: 0.24
# Epoch 740, Loss: 0.48868274688720703, Remaining Time at This Epoch: 0.24
# Epoch 750, Loss: 0.5047475099563599, Remaining Time at This Epoch: 0.24
# Epoch 760, Loss: 0.5185009837150574, Remaining Time at This Epoch: 0.23
# Epoch 770, Loss: 0.49214279651641846, Remaining Time at This Epoch: 0.25
# Epoch 780, Loss: 0.4523739516735077, Remaining Time at This Epoch: 0.23
# Epoch 790, Loss: 0.5254676938056946, Remaining Time at This Epoch: 0.27
# Epoch 800, Loss: 0.4855228364467621, Remaining Time at This Epoch: 0.26
# Epoch 810, Loss: 0.516025722026825, Remaining Time at This Epoch: 0.26
# Epoch 820, Loss: 0.471317321062088, Remaining Time at This Epoch: 0.28
# Epoch 830, Loss: 0.48324063420295715, Remaining Time at This Epoch: 0.26
# Epoch 840, Loss: 0.444259375333786, Remaining Time at This Epoch: 0.26
# Epoch 850, Loss: 0.5145151019096375, Remaining Time at This Epoch: 0.26
# Epoch 860, Loss: 0.48150527477264404, Remaining Time at This Epoch: 0.27
# Epoch 870, Loss: 0.49143052101135254, Remaining Time at This Epoch: 0.28
# Epoch 880, Loss: 0.46652480959892273, Remaining Time at This Epoch: 0.28
# Epoch 890, Loss: 0.5754618644714355, Remaining Time at This Epoch: 0.26
# Epoch 900, Loss: 0.4616873562335968, Remaining Time at This Epoch: 0.28
# Epoch 910, Loss: 0.4784223139286041, Remaining Time at This Epoch: 0.29
# Epoch 920, Loss: 0.47421860694885254, Remaining Time at This Epoch: 0.23
# Epoch 930, Loss: 0.4828398823738098, Remaining Time at This Epoch: 0.24
# Epoch 940, Loss: 0.5057259202003479, Remaining Time at This Epoch: 0.26
# Epoch 950, Loss: 0.47356414794921875, Remaining Time at This Epoch: 0.27
# Epoch 960, Loss: 0.4843553304672241, Remaining Time at This Epoch: 0.25
# Epoch 970, Loss: 0.501253604888916, Remaining Time at This Epoch: 0.24
# Epoch 980, Loss: 0.4718964397907257, Remaining Time at This Epoch: 0.25
# Epoch 990, Loss: 0.4946613013744354, Remaining Time at This Epoch: 0.24
# Epoch 1000, Loss: 0.5191423296928406, Remaining Time at This Epoch: 0.25

# %%
n = 20
flag_sample = 1

for x_input, y_input in train_dataset:
    if flag_sample == 1:        
        x_input_sample, y_input_sample = map(lambda x: x[:n], (x_input, y_input))
        z = model.encode(x_input_sample).numpy()

        fig1, axarr1 = plt.subplots(2, n, figsize=(n, 2))
        x_input_sample = x_input_sample.numpy().reshape([n, 64, 64])
        x_output = model.decode(z).numpy().reshape([n, 64, 64])

        for i in range(n):
            axarr1[0, i].axis('off')
            axarr1[1, i].axis('off')
            axarr1[0, i].imshow(x_input_sample[i],cmap=plt.cm.gray)
            axarr1[1, i].imshow(x_output[i],cmap=plt.cm.gray)

        fig1.savefig("FA_results/"+model_ID+"_reconstruction.png")
        
        z = model.encode(x_input)
        Z_array = z.numpy()
        Label_array = y_input
        flag_sample = 0
    else:
        continue
        # z = model.encode(x_input)
        # Z_array = np.concatenate((Z_array,z.numpy()), axis=0)
        # Label_array = np.concatenate((Label_array,y_input.numpy()), axis=0)

# %%
fig_dist = plt.figure(figsize=(8, 8))
ax_dist = fig_dist.add_subplot(111)
ax_dist.scatter(Z_array[:,0], Z_array[:,1], color='blue',s=0.5)
fig_dist.savefig("FA_results/"+model_ID+"_distribution.png")

# %%
# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 500
seed = 30
rng = np.random.RandomState(seed)
# Anisotropicly distributed data
random_state = 170
no_structure = rng.rand(n_samples, 2), None
# ============
# Set up cluster parameters
# ============
fig_clustering = plt.figure(figsize=(5, 5))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.05, hspace=0.01
)

plot_num = 1

default_base = {
    "quantile": 0.3,
    "eps": 0.3,
    "damping": 0.9,
    "preference": -200,
    "n_neighbors": 3,
    "n_clusters": 4,
    "min_samples": 7,
    "xi": 0.05,
    "min_cluster_size": 0.1,
    "allow_single_cluster": True,
    "hdbscan_min_cluster_size": 15,
    "hdbscan_min_samples": 3,
    "random_state": 42,
}

datasets = [
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    
    params = default_base.copy()
    params.update(algo_params)
   
    X = Z_array
    y = np.zeros(X.shape[0])

    # estimate bandwidth for mean shift
    bandwidth = cluster.estimate_bandwidth(X, quantile=params["quantile"])

    # connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params["n_neighbors"], include_self=False
    )
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)

    # ============
    # Create cluster objects
    # ============
    ms = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=True)
    two_means = cluster.MiniBatchKMeans(
        n_clusters=params["n_clusters"],
        random_state=params["random_state"],
    )
    spectral = cluster.SpectralClustering(
        n_clusters=params["n_clusters"],
        eigen_solver="arpack",
        affinity="nearest_neighbors",
        random_state=params["random_state"],
    )
    
    clustering_algorithms = (
        # ("MeanShift", ms),
        ("Spectral\nClustering", spectral),
        # ("MiniBatch\nKMeans", two_means),
    )

    for name, algorithm in clustering_algorithms:
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the "
                + "connectivity matrix is [0-9]{1,2}"
                + " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning,
            )
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding"
                + " may not work as expected.",
                category=UserWarning,
            )
            algorithm.fit(X)

        t1 = time.time()
        if hasattr(algorithm, "labels_"):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X)


        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(
            list(
                islice(
                    cycle(
                        [
                            "#377eb8",
                            "#ff7f00",
                            "#4daf4a",
                            "#f781bf",
                            "#a65628",
                            "#984ea3",
                            "#999999",
                            "#e41a1c",
                            "#dede00",
                        ]
                    ),
                    int(max(y_pred) + 1),
                )
            )
        )
        # add black color for outliers (if any)
        colors = np.append(colors, ["#000000"])
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xticks(())
        plt.yticks(())
        plt.text(
            0.99,
            0.01,
            ("%.2fs" % (t1 - t0)).lstrip("0"),
            transform=plt.gca().transAxes,
            size=15,
            horizontalalignment="right",
        )
        plot_num += 1

plt.show()

fig_clustering.savefig("results/"+model_ID+"_clustering.png")

# %%
# dec_dir = '/net/projects/CLS/actomyosin_dynamics/data/decoded_results/'

# dec_dir = '/mnt/d/lding/FA/analysis_results/encoder/decoded_results/'


# if not os.path.isdir(dec_dir):          
#     os.mkdir(dec_dir)

# now=datetime.now()
# current_time = now.isoformat()[5:19]
# print(current_time)


# model_dec_dir = '/mnt/d/lding/FA/analysis_results/encoder/decoded_results/'+ model_ID+'_' + current_time
# analysis_dir = '/mnt/d/lding/FA/analysis_results/encoder/analysis/'

# if not os.path.isdir(model_dec_dir):          
#     os.mkdir(model_dec_dir)

# if not os.path.isdir(analysis_dir):          
#     os.mkdir(analysis_dir)



# csv_output = pd.DataFrame(columns=['title', 'labelnumber','cluster_ID'])
# for x_input, y_input in train_dataset:
#     z = model.encode(x_input)
#     x_output = model.decode(z).numpy().reshape([len(y_input), 64, 64])
    
#     # y_pred = algorithm.predict(z.numpy())
#     for i in range(z.numpy().shape[0]):
#         input_label = y_input[i].numpy()
#         input_img = x_input[i,:,:,0].numpy().squeeze()
#         output_img = x_output[i,:,:]
#         label_str = str(int(input_label)).zfill(12)
#         ind = np.where(Label_array == input_label)        
#         pred_ID = y_pred[ind[0][0]]        
        
#         title = 't'+label_str[0:4]+'x'+label_str[4:8]+'y'+label_str[8:12]+'ps64.tif'
        
#         # tifffile.imwrite(os.path.join(model_dec_dir,'dec_'+title), output_img)
        
#         s = pd.DataFrame([[title, input_label,pred_ID]], columns=['title', 'labelnumber','cluster_ID'])
#         csv_output = pd.concat([csv_output, s], ignore_index=True, axis=0)
        


# csv_output.to_csv(os.path.join(analysis_dir,model_ID+'_clustering.csv'))
# Out:
# 06-21T10:57:42
# /tmp/ipykernel_1795017/3511090284.py:44: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   csv_output = pd.concat([csv_output, s], ignore_index=True, axis=0)

# %%
z0_max = np.percentile(Z_array[:,0], 99)
z0_min = np.percentile(Z_array[:,0], 1)
z1_max = np.percentile(Z_array[:,1], 99)
z1_min = np.percentile(Z_array[:,1], 1)


nxy = 10
x = np.linspace(z0_min, z0_max,nxy)
y = np.linspace(z1_min, z1_max,nxy)
xv, yv = np.meshgrid(x, y)

# plt.scatter(xv,yv)

zv = np.concatenate((xv.reshape([nxy*nxy,1]),yv.reshape([nxy*nxy,1])), axis=1)

x_output_manifold = model.decode(zv).numpy().reshape([nxy,nxy, 64, 64])


fig_manifold, axarr = plt.subplots(nxy, nxy, figsize=(nxy, nxy))
for i in range(nxy):
    for j in range(nxy):    
        axarr[i, j].axis('off')
        axarr[i, j].imshow(x_output_manifold[i,j,:,:],cmap=plt.cm.gray)
        
    
fig_manifold.savefig("results/"+model_ID+"_manifold.png")
