# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, random_split
import tifffile as tiff
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from PIL import Image

# Custom Dataset Loader for Unlabeled TIFF Images
class UnlabeledTIFFDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = [os.path.join(root_dir, fname) for fname in os.listdir(root_dir) if fname.lower().endswith(('tif', 'tiff'))]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        try:
            image = tiff.imread(img_path).astype(np.float32)   
            image = image * 240
            image[image > 254] = 254
            if image.ndim == 3:
                image = image[0]
            
        except Exception as e:
            print(f"Warning: Skipping unreadable image {img_path} - {e}")
            return self.__getitem__((idx + 1) % len(self.image_paths))

        image = image/255

        if self.transform:
            image = self.transform(image)

        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
        image = image.squeeze(1)
        return image, 0

# Step 1: Define a standard Autoencoder (AE)
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE


class AE(torch.nn.Module):
    def __init__(self, latent_dim=8):
        super(AE, self).__init__()
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 32, 3, stride=2, padding=1),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Conv2d(32, 64, 3, stride=2, padding=1),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Conv2d(64, 128, 3, stride=2, padding=1),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Flatten()
        )
        self.encoder_fc = torch.nn.Sequential(
            torch.nn.Linear(128 * 8 * 8, 1024),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Linear(1024, latent_dim)
        )

        self.decoder_fc = torch.nn.Sequential(
            torch.nn.Linear(latent_dim, 1024),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Linear(1024, 128 * 8 * 8)
        )

        self.decoder = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(128, 64, 3, stride=2, padding=1, output_padding=1),
            torch.nn.LeakyReLU(0.01),
            torch.nn.ConvTranspose2d(64, 32, 3, stride=2, padding=1, output_padding=1),
            torch.nn.LeakyReLU(0.01),
            torch.nn.ConvTranspose2d(32, 1, 3, stride=2, padding=1, output_padding=1),
            torch.nn.Sigmoid()
        )

    def encode(self, x):
        x = self.encoder(x)
        return self.encoder_fc(x)

    def decode(self, z):
        x = self.decoder_fc(z).view(-1, 128, 8, 8)
        return self.decoder(x)

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z), z


def plot_reconstruction_progress(model, dataloader, device, epoch):
    """Plot original vs reconstructed images during training"""
    model.eval()
    with torch.no_grad():
        for x, _ in dataloader:
            x = x.to(device)
            recon, _ = model(x)
            break  # only one batch

    x = x.cpu()
    recon = recon.cpu()

    print(f"Input stats — min: {x.min().item():.4f}, max: {x.max().item():.4f}, mean: {x.mean().item():.4f}, std: {x.std().item():.4f}")
    print(f"Reconstruction stats — min: {recon.min().item():.4f}, max: {recon.max().item():.4f}, mean: {recon.mean().item():.4f}, std: {recon.std().item():.4f}")

    n = min(8, x.size(0))
    fig, axes = plt.subplots(2, n, figsize=(n * 1, 2))
    for i in range(n):
        axes[0, i].imshow(x[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axes[0, i].axis("off")
        axes[1, i].imshow(recon[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axes[1, i].axis("off")
    plt.suptitle(f"Reconstruction at Epoch {epoch}")
    plt.tight_layout()
    plt.show()



# Step 2: Train Autoencoder and Extract Latent Representations
def train_ae(model, train_loader, val_loader, epochs=500, lr=1e-4):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    train_losses, val_losses = [], []

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for x, _ in train_loader:
            x = x.to(device)
            recon, _ = model(x)
            loss = loss_fn(recon, x)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for x, _ in val_loader:
                x = x.to(device)
                recon, _ = model(x)
                loss = loss_fn(recon, x)
                val_loss += loss.item()
        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        if (epoch + 1) % 20 == 0:
            plot_reconstruction_progress(model, val_loader, device, epoch + 1)
            

    # Plot training and validation loss
    plt.plot(range(epochs), train_losses, label='Train Loss')
    plt.plot(range(epochs), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training vs Validation Loss')
    plt.show()

    return model


# Load Data
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_dir = '/mnt/d/lding/FA/analysis_results/panel_annabel_20250217_correction/test/code_org_202503013_seg/patches64_50p_B'
transform = transforms.Compose([    
    transforms.ToTensor()
])
dataset = UnlabeledTIFFDataset(root_dir=data_dir, transform=transform)

# Split dataset into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# Train AE
ae = AE().to(device)
ae = train_ae(ae, train_loader, val_loader)
# Out:
# /tmp/ipykernel_1134607/4152783461.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
# Epoch 1/500, Train Loss: 0.1576, Val Loss: 0.1489
# Epoch 2/500, Train Loss: 0.1545, Val Loss: 0.1473
# Epoch 3/500, Train Loss: 0.1537, Val Loss: 0.1446
# Epoch 4/500, Train Loss: 0.1529, Val Loss: 0.1383
# Epoch 5/500, Train Loss: 0.1429, Val Loss: 0.1222
# Epoch 6/500, Train Loss: 0.1195, Val Loss: 0.0877
# Epoch 7/500, Train Loss: 0.0750, Val Loss: 0.0470
# Epoch 8/500, Train Loss: 0.0393, Val Loss: 0.0302
# Epoch 9/500, Train Loss: 0.0263, Val Loss: 0.0298
# Epoch 10/500, Train Loss: 0.0249, Val Loss: 0.0309
# Epoch 11/500, Train Loss: 0.0255, Val Loss: 0.0315
# Epoch 12/500, Train Loss: 0.0291, Val Loss: 0.0317
# Epoch 13/500, Train Loss: 0.0287, Val Loss: 0.0318
# Epoch 14/500, Train Loss: 0.0283, Val Loss: 0.0318
# Epoch 15/500, Train Loss: 0.0292, Val Loss: 0.0317
# Epoch 16/500, Train Loss: 0.0290, Val Loss: 0.0317
# Epoch 17/500, Train Loss: 0.0266, Val Loss: 0.0316
# Epoch 18/500, Train Loss: 0.0281, Val Loss: 0.0315
# Epoch 19/500, Train Loss: 0.0282, Val Loss: 0.0314
# Epoch 20/500, Train Loss: 0.0309, Val Loss: 0.0311
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0000, max: 0.2241, mean: 0.0075, std: 0.0242
# Epoch 21/500, Train Loss: 0.0275, Val Loss: 0.0307
# Epoch 22/500, Train Loss: 0.0309, Val Loss: 0.0301
# Epoch 23/500, Train Loss: 0.0274, Val Loss: 0.0287
# Epoch 24/500, Train Loss: 0.0256, Val Loss: 0.0261
# Epoch 25/500, Train Loss: 0.0231, Val Loss: 0.0233
# Epoch 26/500, Train Loss: 0.0209, Val Loss: 0.0208
# Epoch 27/500, Train Loss: 0.0184, Val Loss: 0.0175
# Epoch 28/500, Train Loss: 0.0159, Val Loss: 0.0147
# Epoch 29/500, Train Loss: 0.0131, Val Loss: 0.0134
# Epoch 30/500, Train Loss: 0.0123, Val Loss: 0.0129
# Epoch 31/500, Train Loss: 0.0125, Val Loss: 0.0124
# Epoch 32/500, Train Loss: 0.0114, Val Loss: 0.0121
# Epoch 33/500, Train Loss: 0.0109, Val Loss: 0.0115
# Epoch 34/500, Train Loss: 0.0105, Val Loss: 0.0112
# Epoch 35/500, Train Loss: 0.0107, Val Loss: 0.0110
# Epoch 36/500, Train Loss: 0.0098, Val Loss: 0.0107
# Epoch 37/500, Train Loss: 0.0107, Val Loss: 0.0106
# Epoch 38/500, Train Loss: 0.0095, Val Loss: 0.0105
# Epoch 39/500, Train Loss: 0.0096, Val Loss: 0.0104
# Epoch 40/500, Train Loss: 0.0096, Val Loss: 0.0103
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0059, max: 0.4153, mean: 0.1236, std: 0.0832
# Epoch 41/500, Train Loss: 0.0095, Val Loss: 0.0103
# Epoch 42/500, Train Loss: 0.0101, Val Loss: 0.0103
# Epoch 43/500, Train Loss: 0.0095, Val Loss: 0.0102
# Epoch 44/500, Train Loss: 0.0099, Val Loss: 0.0102
# Epoch 45/500, Train Loss: 0.0093, Val Loss: 0.0102
# Epoch 46/500, Train Loss: 0.0099, Val Loss: 0.0102
# Epoch 47/500, Train Loss: 0.0091, Val Loss: 0.0102
# Epoch 48/500, Train Loss: 0.0097, Val Loss: 0.0101
# Epoch 49/500, Train Loss: 0.0099, Val Loss: 0.0101
# Epoch 50/500, Train Loss: 0.0097, Val Loss: 0.0101
# Epoch 51/500, Train Loss: 0.0104, Val Loss: 0.0101
# Epoch 52/500, Train Loss: 0.0092, Val Loss: 0.0101
# Epoch 53/500, Train Loss: 0.0099, Val Loss: 0.0102
# Epoch 54/500, Train Loss: 0.0094, Val Loss: 0.0101
# Epoch 55/500, Train Loss: 0.0101, Val Loss: 0.0101
# Epoch 56/500, Train Loss: 0.0095, Val Loss: 0.0101
# Epoch 57/500, Train Loss: 0.0099, Val Loss: 0.0101
# Epoch 58/500, Train Loss: 0.0101, Val Loss: 0.0101
# Epoch 59/500, Train Loss: 0.0094, Val Loss: 0.0101
# Epoch 60/500, Train Loss: 0.0097, Val Loss: 0.0101
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0093, max: 0.4161, mean: 0.1273, std: 0.0819
# Epoch 61/500, Train Loss: 0.0092, Val Loss: 0.0101
# Epoch 62/500, Train Loss: 0.0093, Val Loss: 0.0101
# Epoch 63/500, Train Loss: 0.0090, Val Loss: 0.0101
# Epoch 64/500, Train Loss: 0.0089, Val Loss: 0.0101
# Epoch 65/500, Train Loss: 0.0097, Val Loss: 0.0101
# Epoch 66/500, Train Loss: 0.0101, Val Loss: 0.0101
# Epoch 67/500, Train Loss: 0.0092, Val Loss: 0.0100
# Epoch 68/500, Train Loss: 0.0091, Val Loss: 0.0100
# Epoch 69/500, Train Loss: 0.0100, Val Loss: 0.0100
# Epoch 70/500, Train Loss: 0.0096, Val Loss: 0.0100
# Epoch 71/500, Train Loss: 0.0097, Val Loss: 0.0100
# Epoch 72/500, Train Loss: 0.0089, Val Loss: 0.0101
# Epoch 73/500, Train Loss: 0.0093, Val Loss: 0.0101
# Epoch 74/500, Train Loss: 0.0102, Val Loss: 0.0101
# Epoch 75/500, Train Loss: 0.0099, Val Loss: 0.0101
# Epoch 76/500, Train Loss: 0.0097, Val Loss: 0.0101
# Epoch 77/500, Train Loss: 0.0096, Val Loss: 0.0100
# Epoch 78/500, Train Loss: 0.0096, Val Loss: 0.0100
# Epoch 79/500, Train Loss: 0.0101, Val Loss: 0.0100
# Epoch 80/500, Train Loss: 0.0105, Val Loss: 0.0100
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0096, max: 0.4442, mean: 0.1233, std: 0.0820
# Epoch 81/500, Train Loss: 0.0095, Val Loss: 0.0100
# Epoch 82/500, Train Loss: 0.0101, Val Loss: 0.0101
# Epoch 83/500, Train Loss: 0.0096, Val Loss: 0.0100
# Epoch 84/500, Train Loss: 0.0090, Val Loss: 0.0100
# Epoch 85/500, Train Loss: 0.0096, Val Loss: 0.0100
# Epoch 86/500, Train Loss: 0.0097, Val Loss: 0.0100
# Epoch 87/500, Train Loss: 0.0088, Val Loss: 0.0100
# Epoch 88/500, Train Loss: 0.0095, Val Loss: 0.0100
# Epoch 89/500, Train Loss: 0.0099, Val Loss: 0.0100
# Epoch 90/500, Train Loss: 0.0093, Val Loss: 0.0100
# Epoch 91/500, Train Loss: 0.0091, Val Loss: 0.0100
# Epoch 92/500, Train Loss: 0.0090, Val Loss: 0.0099
# Epoch 93/500, Train Loss: 0.0090, Val Loss: 0.0099
# Epoch 94/500, Train Loss: 0.0101, Val Loss: 0.0099
# Epoch 95/500, Train Loss: 0.0095, Val Loss: 0.0099
# Epoch 96/500, Train Loss: 0.0092, Val Loss: 0.0098
# Epoch 97/500, Train Loss: 0.0085, Val Loss: 0.0098
# Epoch 98/500, Train Loss: 0.0086, Val Loss: 0.0098
# Epoch 99/500, Train Loss: 0.0090, Val Loss: 0.0098
# Epoch 100/500, Train Loss: 0.0086, Val Loss: 0.0098
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0097, max: 0.4952, mean: 0.1254, std: 0.0828
# Epoch 101/500, Train Loss: 0.0095, Val Loss: 0.0097
# Epoch 102/500, Train Loss: 0.0095, Val Loss: 0.0097
# Epoch 103/500, Train Loss: 0.0088, Val Loss: 0.0096
# Epoch 104/500, Train Loss: 0.0084, Val Loss: 0.0096
# Epoch 105/500, Train Loss: 0.0088, Val Loss: 0.0095
# Epoch 106/500, Train Loss: 0.0092, Val Loss: 0.0094
# Epoch 107/500, Train Loss: 0.0087, Val Loss: 0.0094
# Epoch 108/500, Train Loss: 0.0085, Val Loss: 0.0093
# Epoch 109/500, Train Loss: 0.0080, Val Loss: 0.0093
# Epoch 110/500, Train Loss: 0.0085, Val Loss: 0.0093
# Epoch 111/500, Train Loss: 0.0084, Val Loss: 0.0092
# Epoch 112/500, Train Loss: 0.0082, Val Loss: 0.0092
# Epoch 113/500, Train Loss: 0.0080, Val Loss: 0.0092
# Epoch 114/500, Train Loss: 0.0089, Val Loss: 0.0092
# Epoch 115/500, Train Loss: 0.0079, Val Loss: 0.0092
# Epoch 116/500, Train Loss: 0.0080, Val Loss: 0.0091
# Epoch 117/500, Train Loss: 0.0088, Val Loss: 0.0091
# Epoch 118/500, Train Loss: 0.0080, Val Loss: 0.0091
# Epoch 119/500, Train Loss: 0.0085, Val Loss: 0.0091
# Epoch 120/500, Train Loss: 0.0085, Val Loss: 0.0090
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0097, max: 0.5167, mean: 0.1248, std: 0.0874
# Epoch 121/500, Train Loss: 0.0081, Val Loss: 0.0090
# Epoch 122/500, Train Loss: 0.0080, Val Loss: 0.0089
# Epoch 123/500, Train Loss: 0.0082, Val Loss: 0.0089
# Epoch 124/500, Train Loss: 0.0075, Val Loss: 0.0089
# Epoch 125/500, Train Loss: 0.0076, Val Loss: 0.0089
# Epoch 126/500, Train Loss: 0.0077, Val Loss: 0.0088
# Epoch 127/500, Train Loss: 0.0079, Val Loss: 0.0088
# Epoch 128/500, Train Loss: 0.0077, Val Loss: 0.0088
# Epoch 129/500, Train Loss: 0.0077, Val Loss: 0.0087
# Epoch 130/500, Train Loss: 0.0080, Val Loss: 0.0087
# Epoch 131/500, Train Loss: 0.0083, Val Loss: 0.0087
# Epoch 132/500, Train Loss: 0.0074, Val Loss: 0.0087
# Epoch 133/500, Train Loss: 0.0079, Val Loss: 0.0087
# Epoch 134/500, Train Loss: 0.0074, Val Loss: 0.0087
# Epoch 135/500, Train Loss: 0.0079, Val Loss: 0.0086
# Epoch 136/500, Train Loss: 0.0079, Val Loss: 0.0086
# Epoch 137/500, Train Loss: 0.0078, Val Loss: 0.0086
# Epoch 138/500, Train Loss: 0.0071, Val Loss: 0.0086
# Epoch 139/500, Train Loss: 0.0076, Val Loss: 0.0086
# Epoch 140/500, Train Loss: 0.0074, Val Loss: 0.0086
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0103, max: 0.6206, mean: 0.1264, std: 0.0919
# Epoch 141/500, Train Loss: 0.0079, Val Loss: 0.0085
# Epoch 142/500, Train Loss: 0.0071, Val Loss: 0.0085
# Epoch 143/500, Train Loss: 0.0076, Val Loss: 0.0085
# Epoch 144/500, Train Loss: 0.0075, Val Loss: 0.0085
# Epoch 145/500, Train Loss: 0.0073, Val Loss: 0.0085
# Epoch 146/500, Train Loss: 0.0074, Val Loss: 0.0085
# Epoch 147/500, Train Loss: 0.0070, Val Loss: 0.0085
# Epoch 148/500, Train Loss: 0.0069, Val Loss: 0.0085
# Epoch 149/500, Train Loss: 0.0073, Val Loss: 0.0085
# Epoch 150/500, Train Loss: 0.0076, Val Loss: 0.0085
# Epoch 151/500, Train Loss: 0.0072, Val Loss: 0.0085
# Epoch 152/500, Train Loss: 0.0072, Val Loss: 0.0085
# Epoch 153/500, Train Loss: 0.0073, Val Loss: 0.0085
# Epoch 154/500, Train Loss: 0.0071, Val Loss: 0.0085
# Epoch 155/500, Train Loss: 0.0069, Val Loss: 0.0085
# Epoch 156/500, Train Loss: 0.0071, Val Loss: 0.0085
# Epoch 157/500, Train Loss: 0.0068, Val Loss: 0.0085
# Epoch 158/500, Train Loss: 0.0070, Val Loss: 0.0085
# Epoch 159/500, Train Loss: 0.0066, Val Loss: 0.0085
# Epoch 160/500, Train Loss: 0.0072, Val Loss: 0.0085
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0098, max: 0.6824, mean: 0.1287, std: 0.0959
# Epoch 161/500, Train Loss: 0.0069, Val Loss: 0.0085
# Epoch 162/500, Train Loss: 0.0071, Val Loss: 0.0085
# Epoch 163/500, Train Loss: 0.0069, Val Loss: 0.0085
# Epoch 164/500, Train Loss: 0.0066, Val Loss: 0.0085
# Epoch 165/500, Train Loss: 0.0068, Val Loss: 0.0085
# Epoch 166/500, Train Loss: 0.0066, Val Loss: 0.0085
# Epoch 167/500, Train Loss: 0.0071, Val Loss: 0.0084
# Epoch 168/500, Train Loss: 0.0065, Val Loss: 0.0085
# Epoch 169/500, Train Loss: 0.0067, Val Loss: 0.0085
# Epoch 170/500, Train Loss: 0.0068, Val Loss: 0.0085
# Epoch 171/500, Train Loss: 0.0071, Val Loss: 0.0085
# Epoch 172/500, Train Loss: 0.0067, Val Loss: 0.0085
# Epoch 173/500, Train Loss: 0.0067, Val Loss: 0.0085
# Epoch 174/500, Train Loss: 0.0066, Val Loss: 0.0085
# Epoch 175/500, Train Loss: 0.0063, Val Loss: 0.0085
# Epoch 176/500, Train Loss: 0.0066, Val Loss: 0.0084
# Epoch 177/500, Train Loss: 0.0071, Val Loss: 0.0085
# Epoch 178/500, Train Loss: 0.0069, Val Loss: 0.0085
# Epoch 179/500, Train Loss: 0.0070, Val Loss: 0.0085
# Epoch 180/500, Train Loss: 0.0065, Val Loss: 0.0084
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0097, max: 0.7269, mean: 0.1276, std: 0.0945
# Epoch 181/500, Train Loss: 0.0064, Val Loss: 0.0086
# Epoch 182/500, Train Loss: 0.0063, Val Loss: 0.0085
# Epoch 183/500, Train Loss: 0.0066, Val Loss: 0.0084
# Epoch 184/500, Train Loss: 0.0068, Val Loss: 0.0084
# Epoch 185/500, Train Loss: 0.0067, Val Loss: 0.0084
# Epoch 186/500, Train Loss: 0.0068, Val Loss: 0.0085
# Epoch 187/500, Train Loss: 0.0067, Val Loss: 0.0084
# Epoch 188/500, Train Loss: 0.0069, Val Loss: 0.0085
# Epoch 189/500, Train Loss: 0.0065, Val Loss: 0.0085
# Epoch 190/500, Train Loss: 0.0068, Val Loss: 0.0085
# Epoch 191/500, Train Loss: 0.0066, Val Loss: 0.0085
# Epoch 192/500, Train Loss: 0.0063, Val Loss: 0.0085
# Epoch 193/500, Train Loss: 0.0064, Val Loss: 0.0085
# Epoch 194/500, Train Loss: 0.0063, Val Loss: 0.0085
# Epoch 195/500, Train Loss: 0.0064, Val Loss: 0.0085
# Epoch 196/500, Train Loss: 0.0061, Val Loss: 0.0085
# Epoch 197/500, Train Loss: 0.0061, Val Loss: 0.0085
# Epoch 198/500, Train Loss: 0.0061, Val Loss: 0.0085
# Epoch 199/500, Train Loss: 0.0063, Val Loss: 0.0085
# Epoch 200/500, Train Loss: 0.0063, Val Loss: 0.0085
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0085, max: 0.7802, mean: 0.1269, std: 0.0973
# Epoch 201/500, Train Loss: 0.0061, Val Loss: 0.0085
# Epoch 202/500, Train Loss: 0.0065, Val Loss: 0.0085
# Epoch 203/500, Train Loss: 0.0063, Val Loss: 0.0085
# Epoch 204/500, Train Loss: 0.0060, Val Loss: 0.0085
# Epoch 205/500, Train Loss: 0.0062, Val Loss: 0.0085
# Epoch 206/500, Train Loss: 0.0063, Val Loss: 0.0085
# Epoch 207/500, Train Loss: 0.0061, Val Loss: 0.0086
# Epoch 208/500, Train Loss: 0.0062, Val Loss: 0.0086
# Epoch 209/500, Train Loss: 0.0063, Val Loss: 0.0086
# Epoch 210/500, Train Loss: 0.0063, Val Loss: 0.0086
# Epoch 211/500, Train Loss: 0.0063, Val Loss: 0.0086
# Epoch 212/500, Train Loss: 0.0059, Val Loss: 0.0086
# Epoch 213/500, Train Loss: 0.0058, Val Loss: 0.0086
# Epoch 214/500, Train Loss: 0.0059, Val Loss: 0.0086
# Epoch 215/500, Train Loss: 0.0061, Val Loss: 0.0086
# Epoch 216/500, Train Loss: 0.0057, Val Loss: 0.0086
# Epoch 217/500, Train Loss: 0.0057, Val Loss: 0.0086
# Epoch 218/500, Train Loss: 0.0059, Val Loss: 0.0086
# Epoch 219/500, Train Loss: 0.0060, Val Loss: 0.0086
# Epoch 220/500, Train Loss: 0.0059, Val Loss: 0.0086
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0059, max: 0.8471, mean: 0.1242, std: 0.0963
# Epoch 221/500, Train Loss: 0.0060, Val Loss: 0.0086
# Epoch 222/500, Train Loss: 0.0059, Val Loss: 0.0086
# Epoch 223/500, Train Loss: 0.0059, Val Loss: 0.0086
# Epoch 224/500, Train Loss: 0.0060, Val Loss: 0.0086
# Epoch 225/500, Train Loss: 0.0060, Val Loss: 0.0086
# Epoch 226/500, Train Loss: 0.0060, Val Loss: 0.0086
# Epoch 227/500, Train Loss: 0.0058, Val Loss: 0.0087
# Epoch 228/500, Train Loss: 0.0058, Val Loss: 0.0087
# Epoch 229/500, Train Loss: 0.0058, Val Loss: 0.0087
# Epoch 230/500, Train Loss: 0.0060, Val Loss: 0.0087
# Epoch 231/500, Train Loss: 0.0058, Val Loss: 0.0088
# Epoch 232/500, Train Loss: 0.0059, Val Loss: 0.0088
# Epoch 233/500, Train Loss: 0.0061, Val Loss: 0.0087
# Epoch 234/500, Train Loss: 0.0059, Val Loss: 0.0087
# Epoch 235/500, Train Loss: 0.0056, Val Loss: 0.0087
# Epoch 236/500, Train Loss: 0.0059, Val Loss: 0.0087
# Epoch 237/500, Train Loss: 0.0058, Val Loss: 0.0088
# Epoch 238/500, Train Loss: 0.0055, Val Loss: 0.0088
# Epoch 239/500, Train Loss: 0.0058, Val Loss: 0.0088
# Epoch 240/500, Train Loss: 0.0055, Val Loss: 0.0088
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0056, max: 0.9099, mean: 0.1280, std: 0.1010
# Epoch 241/500, Train Loss: 0.0057, Val Loss: 0.0088
# Epoch 242/500, Train Loss: 0.0058, Val Loss: 0.0088
# Epoch 243/500, Train Loss: 0.0059, Val Loss: 0.0088
# Epoch 244/500, Train Loss: 0.0056, Val Loss: 0.0088
# Epoch 245/500, Train Loss: 0.0058, Val Loss: 0.0088
# Epoch 246/500, Train Loss: 0.0056, Val Loss: 0.0088
# Epoch 247/500, Train Loss: 0.0057, Val Loss: 0.0088
# Epoch 248/500, Train Loss: 0.0058, Val Loss: 0.0088
# Epoch 249/500, Train Loss: 0.0057, Val Loss: 0.0088
# Epoch 250/500, Train Loss: 0.0060, Val Loss: 0.0089
# Epoch 251/500, Train Loss: 0.0055, Val Loss: 0.0088
# Epoch 252/500, Train Loss: 0.0056, Val Loss: 0.0089
# Epoch 253/500, Train Loss: 0.0055, Val Loss: 0.0088
# Epoch 254/500, Train Loss: 0.0058, Val Loss: 0.0088
# Epoch 255/500, Train Loss: 0.0054, Val Loss: 0.0089
# Epoch 256/500, Train Loss: 0.0054, Val Loss: 0.0089
# Epoch 257/500, Train Loss: 0.0056, Val Loss: 0.0088
# Epoch 258/500, Train Loss: 0.0058, Val Loss: 0.0089
# Epoch 259/500, Train Loss: 0.0060, Val Loss: 0.0089
# Epoch 260/500, Train Loss: 0.0054, Val Loss: 0.0089
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0055, max: 0.9149, mean: 0.1228, std: 0.0986
# Epoch 261/500, Train Loss: 0.0052, Val Loss: 0.0089
# Epoch 262/500, Train Loss: 0.0057, Val Loss: 0.0089
# Epoch 263/500, Train Loss: 0.0052, Val Loss: 0.0090
# Epoch 264/500, Train Loss: 0.0057, Val Loss: 0.0090
# Epoch 265/500, Train Loss: 0.0055, Val Loss: 0.0089
# Epoch 266/500, Train Loss: 0.0053, Val Loss: 0.0089
# Epoch 267/500, Train Loss: 0.0054, Val Loss: 0.0090
# Epoch 268/500, Train Loss: 0.0052, Val Loss: 0.0090
# Epoch 269/500, Train Loss: 0.0056, Val Loss: 0.0089
# Epoch 270/500, Train Loss: 0.0054, Val Loss: 0.0090
# Epoch 271/500, Train Loss: 0.0053, Val Loss: 0.0090
# Epoch 272/500, Train Loss: 0.0054, Val Loss: 0.0089
# Epoch 273/500, Train Loss: 0.0055, Val Loss: 0.0090
# Epoch 274/500, Train Loss: 0.0053, Val Loss: 0.0090
# Epoch 275/500, Train Loss: 0.0056, Val Loss: 0.0091
# Epoch 276/500, Train Loss: 0.0051, Val Loss: 0.0091
# Epoch 277/500, Train Loss: 0.0053, Val Loss: 0.0090
# Epoch 278/500, Train Loss: 0.0057, Val Loss: 0.0090
# Epoch 279/500, Train Loss: 0.0055, Val Loss: 0.0091
# Epoch 280/500, Train Loss: 0.0055, Val Loss: 0.0091
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0040, max: 0.8958, mean: 0.1285, std: 0.1018
# Epoch 281/500, Train Loss: 0.0054, Val Loss: 0.0091
# Epoch 282/500, Train Loss: 0.0051, Val Loss: 0.0091
# Epoch 283/500, Train Loss: 0.0053, Val Loss: 0.0091
# Epoch 284/500, Train Loss: 0.0051, Val Loss: 0.0091
# Epoch 285/500, Train Loss: 0.0053, Val Loss: 0.0091
# Epoch 286/500, Train Loss: 0.0054, Val Loss: 0.0091
# Epoch 287/500, Train Loss: 0.0052, Val Loss: 0.0090
# Epoch 288/500, Train Loss: 0.0054, Val Loss: 0.0090
# Epoch 289/500, Train Loss: 0.0053, Val Loss: 0.0091
# Epoch 290/500, Train Loss: 0.0051, Val Loss: 0.0090
# Epoch 291/500, Train Loss: 0.0049, Val Loss: 0.0091
# Epoch 292/500, Train Loss: 0.0050, Val Loss: 0.0091
# Epoch 293/500, Train Loss: 0.0050, Val Loss: 0.0092
# Epoch 294/500, Train Loss: 0.0052, Val Loss: 0.0091
# Epoch 295/500, Train Loss: 0.0052, Val Loss: 0.0092
# Epoch 296/500, Train Loss: 0.0052, Val Loss: 0.0091
# Epoch 297/500, Train Loss: 0.0052, Val Loss: 0.0091
# Epoch 298/500, Train Loss: 0.0052, Val Loss: 0.0091
# Epoch 299/500, Train Loss: 0.0051, Val Loss: 0.0092
# Epoch 300/500, Train Loss: 0.0053, Val Loss: 0.0092
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0041, max: 0.8799, mean: 0.1260, std: 0.1005
# Epoch 301/500, Train Loss: 0.0050, Val Loss: 0.0092
# Epoch 302/500, Train Loss: 0.0052, Val Loss: 0.0092
# Epoch 303/500, Train Loss: 0.0051, Val Loss: 0.0092
# Epoch 304/500, Train Loss: 0.0052, Val Loss: 0.0092
# Epoch 305/500, Train Loss: 0.0051, Val Loss: 0.0092
# Epoch 306/500, Train Loss: 0.0054, Val Loss: 0.0092
# Epoch 307/500, Train Loss: 0.0050, Val Loss: 0.0092
# Epoch 308/500, Train Loss: 0.0053, Val Loss: 0.0092
# Epoch 309/500, Train Loss: 0.0053, Val Loss: 0.0092
# Epoch 310/500, Train Loss: 0.0054, Val Loss: 0.0093
# Epoch 311/500, Train Loss: 0.0051, Val Loss: 0.0093
# Epoch 312/500, Train Loss: 0.0051, Val Loss: 0.0093
# Epoch 313/500, Train Loss: 0.0047, Val Loss: 0.0093
# Epoch 314/500, Train Loss: 0.0049, Val Loss: 0.0093
# Epoch 315/500, Train Loss: 0.0048, Val Loss: 0.0092
# Epoch 316/500, Train Loss: 0.0050, Val Loss: 0.0092
# Epoch 317/500, Train Loss: 0.0051, Val Loss: 0.0093
# Epoch 318/500, Train Loss: 0.0051, Val Loss: 0.0093
# Epoch 319/500, Train Loss: 0.0050, Val Loss: 0.0093
# Epoch 320/500, Train Loss: 0.0050, Val Loss: 0.0093
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0035, max: 0.9038, mean: 0.1248, std: 0.1013
# Epoch 321/500, Train Loss: 0.0048, Val Loss: 0.0094
# Epoch 322/500, Train Loss: 0.0049, Val Loss: 0.0094
# Epoch 323/500, Train Loss: 0.0050, Val Loss: 0.0093
# Epoch 324/500, Train Loss: 0.0050, Val Loss: 0.0093
# Epoch 325/500, Train Loss: 0.0048, Val Loss: 0.0094
# Epoch 326/500, Train Loss: 0.0048, Val Loss: 0.0093
# Epoch 327/500, Train Loss: 0.0049, Val Loss: 0.0093
# Epoch 328/500, Train Loss: 0.0050, Val Loss: 0.0093
# Epoch 329/500, Train Loss: 0.0050, Val Loss: 0.0093
# Epoch 330/500, Train Loss: 0.0051, Val Loss: 0.0093
# Epoch 331/500, Train Loss: 0.0047, Val Loss: 0.0093
# Epoch 332/500, Train Loss: 0.0048, Val Loss: 0.0094
# Epoch 333/500, Train Loss: 0.0047, Val Loss: 0.0094
# Epoch 334/500, Train Loss: 0.0047, Val Loss: 0.0094
# Epoch 335/500, Train Loss: 0.0050, Val Loss: 0.0094
# Epoch 336/500, Train Loss: 0.0050, Val Loss: 0.0094
# Epoch 337/500, Train Loss: 0.0047, Val Loss: 0.0094
# Epoch 338/500, Train Loss: 0.0048, Val Loss: 0.0095
# Epoch 339/500, Train Loss: 0.0050, Val Loss: 0.0095
# Epoch 340/500, Train Loss: 0.0048, Val Loss: 0.0095
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0032, max: 0.9255, mean: 0.1279, std: 0.1026
# Epoch 341/500, Train Loss: 0.0047, Val Loss: 0.0095
# Epoch 342/500, Train Loss: 0.0048, Val Loss: 0.0095
# Epoch 343/500, Train Loss: 0.0050, Val Loss: 0.0095
# Epoch 344/500, Train Loss: 0.0047, Val Loss: 0.0095
# Epoch 345/500, Train Loss: 0.0047, Val Loss: 0.0095
# Epoch 346/500, Train Loss: 0.0046, Val Loss: 0.0095
# Epoch 347/500, Train Loss: 0.0050, Val Loss: 0.0095
# Epoch 348/500, Train Loss: 0.0044, Val Loss: 0.0095
# Epoch 349/500, Train Loss: 0.0049, Val Loss: 0.0096
# Epoch 350/500, Train Loss: 0.0045, Val Loss: 0.0095
# Epoch 351/500, Train Loss: 0.0049, Val Loss: 0.0095
# Epoch 352/500, Train Loss: 0.0046, Val Loss: 0.0095
# Epoch 353/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 354/500, Train Loss: 0.0048, Val Loss: 0.0096
# Epoch 355/500, Train Loss: 0.0045, Val Loss: 0.0096
# Epoch 356/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 357/500, Train Loss: 0.0046, Val Loss: 0.0095
# Epoch 358/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 359/500, Train Loss: 0.0045, Val Loss: 0.0096
# Epoch 360/500, Train Loss: 0.0047, Val Loss: 0.0097
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0029, max: 0.9449, mean: 0.1282, std: 0.1044
# Epoch 361/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 362/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 363/500, Train Loss: 0.0047, Val Loss: 0.0097
# Epoch 364/500, Train Loss: 0.0046, Val Loss: 0.0097
# Epoch 365/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 366/500, Train Loss: 0.0046, Val Loss: 0.0096
# Epoch 367/500, Train Loss: 0.0047, Val Loss: 0.0097
# Epoch 368/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 369/500, Train Loss: 0.0045, Val Loss: 0.0096
# Epoch 370/500, Train Loss: 0.0048, Val Loss: 0.0096
# Epoch 371/500, Train Loss: 0.0047, Val Loss: 0.0096
# Epoch 372/500, Train Loss: 0.0045, Val Loss: 0.0097
# Epoch 373/500, Train Loss: 0.0045, Val Loss: 0.0096
# Epoch 374/500, Train Loss: 0.0045, Val Loss: 0.0096
# Epoch 375/500, Train Loss: 0.0044, Val Loss: 0.0097
# Epoch 376/500, Train Loss: 0.0046, Val Loss: 0.0097
# Epoch 377/500, Train Loss: 0.0043, Val Loss: 0.0098
# Epoch 378/500, Train Loss: 0.0045, Val Loss: 0.0098
# Epoch 379/500, Train Loss: 0.0045, Val Loss: 0.0097
# Epoch 380/500, Train Loss: 0.0044, Val Loss: 0.0098
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0027, max: 0.9470, mean: 0.1273, std: 0.1047
# Epoch 381/500, Train Loss: 0.0048, Val Loss: 0.0097
# Epoch 382/500, Train Loss: 0.0045, Val Loss: 0.0097
# Epoch 383/500, Train Loss: 0.0044, Val Loss: 0.0098
# Epoch 384/500, Train Loss: 0.0045, Val Loss: 0.0098
# Epoch 385/500, Train Loss: 0.0044, Val Loss: 0.0098
# Epoch 386/500, Train Loss: 0.0045, Val Loss: 0.0098
# Epoch 387/500, Train Loss: 0.0044, Val Loss: 0.0097
# Epoch 388/500, Train Loss: 0.0044, Val Loss: 0.0097
# Epoch 389/500, Train Loss: 0.0047, Val Loss: 0.0098
# Epoch 390/500, Train Loss: 0.0045, Val Loss: 0.0098
# Epoch 391/500, Train Loss: 0.0044, Val Loss: 0.0097
# Epoch 392/500, Train Loss: 0.0045, Val Loss: 0.0097
# Epoch 393/500, Train Loss: 0.0043, Val Loss: 0.0097
# Epoch 394/500, Train Loss: 0.0044, Val Loss: 0.0098
# Epoch 395/500, Train Loss: 0.0044, Val Loss: 0.0098
# Epoch 396/500, Train Loss: 0.0044, Val Loss: 0.0098
# Epoch 397/500, Train Loss: 0.0044, Val Loss: 0.0098
# Epoch 398/500, Train Loss: 0.0043, Val Loss: 0.0098
# Epoch 399/500, Train Loss: 0.0043, Val Loss: 0.0097
# Epoch 400/500, Train Loss: 0.0043, Val Loss: 0.0098
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0028, max: 0.9463, mean: 0.1213, std: 0.1010
# Epoch 401/500, Train Loss: 0.0042, Val Loss: 0.0098
# Epoch 402/500, Train Loss: 0.0043, Val Loss: 0.0098
# Epoch 403/500, Train Loss: 0.0043, Val Loss: 0.0098
# Epoch 404/500, Train Loss: 0.0041, Val Loss: 0.0098
# Epoch 405/500, Train Loss: 0.0043, Val Loss: 0.0098
# Epoch 406/500, Train Loss: 0.0043, Val Loss: 0.0098
# Epoch 407/500, Train Loss: 0.0043, Val Loss: 0.0099
# Epoch 408/500, Train Loss: 0.0046, Val Loss: 0.0098
# Epoch 409/500, Train Loss: 0.0042, Val Loss: 0.0098
# Epoch 410/500, Train Loss: 0.0040, Val Loss: 0.0098
# Epoch 411/500, Train Loss: 0.0043, Val Loss: 0.0098
# Epoch 412/500, Train Loss: 0.0043, Val Loss: 0.0099
# Epoch 413/500, Train Loss: 0.0045, Val Loss: 0.0099
# Epoch 414/500, Train Loss: 0.0042, Val Loss: 0.0099
# Epoch 415/500, Train Loss: 0.0045, Val Loss: 0.0099
# Epoch 416/500, Train Loss: 0.0044, Val Loss: 0.0099
# Epoch 417/500, Train Loss: 0.0043, Val Loss: 0.0100
# Epoch 418/500, Train Loss: 0.0041, Val Loss: 0.0101
# Epoch 419/500, Train Loss: 0.0042, Val Loss: 0.0100
# Epoch 420/500, Train Loss: 0.0044, Val Loss: 0.0100
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0023, max: 0.9535, mean: 0.1277, std: 0.1054
# Epoch 421/500, Train Loss: 0.0044, Val Loss: 0.0101
# Epoch 422/500, Train Loss: 0.0044, Val Loss: 0.0100
# Epoch 423/500, Train Loss: 0.0041, Val Loss: 0.0101
# Epoch 424/500, Train Loss: 0.0041, Val Loss: 0.0102
# Epoch 425/500, Train Loss: 0.0043, Val Loss: 0.0101
# Epoch 426/500, Train Loss: 0.0040, Val Loss: 0.0100
# Epoch 427/500, Train Loss: 0.0043, Val Loss: 0.0100
# Epoch 428/500, Train Loss: 0.0040, Val Loss: 0.0100
# Epoch 429/500, Train Loss: 0.0045, Val Loss: 0.0100
# Epoch 430/500, Train Loss: 0.0043, Val Loss: 0.0100
# Epoch 431/500, Train Loss: 0.0042, Val Loss: 0.0100
# Epoch 432/500, Train Loss: 0.0042, Val Loss: 0.0100
# Epoch 433/500, Train Loss: 0.0041, Val Loss: 0.0100
# Epoch 434/500, Train Loss: 0.0042, Val Loss: 0.0100
# Epoch 435/500, Train Loss: 0.0040, Val Loss: 0.0100
# Epoch 436/500, Train Loss: 0.0041, Val Loss: 0.0101
# Epoch 437/500, Train Loss: 0.0041, Val Loss: 0.0101
# Epoch 438/500, Train Loss: 0.0040, Val Loss: 0.0101
# Epoch 439/500, Train Loss: 0.0043, Val Loss: 0.0100
# Epoch 440/500, Train Loss: 0.0041, Val Loss: 0.0100
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0012, max: 0.9567, mean: 0.1236, std: 0.1042
# Epoch 441/500, Train Loss: 0.0042, Val Loss: 0.0101
# Epoch 442/500, Train Loss: 0.0042, Val Loss: 0.0101
# Epoch 443/500, Train Loss: 0.0043, Val Loss: 0.0101
# Epoch 444/500, Train Loss: 0.0040, Val Loss: 0.0100
# Epoch 445/500, Train Loss: 0.0040, Val Loss: 0.0101
# Epoch 446/500, Train Loss: 0.0039, Val Loss: 0.0101
# Epoch 447/500, Train Loss: 0.0042, Val Loss: 0.0100
# Epoch 448/500, Train Loss: 0.0040, Val Loss: 0.0101
# Epoch 449/500, Train Loss: 0.0042, Val Loss: 0.0101
# Epoch 450/500, Train Loss: 0.0039, Val Loss: 0.0101
# Epoch 451/500, Train Loss: 0.0040, Val Loss: 0.0101
# Epoch 452/500, Train Loss: 0.0041, Val Loss: 0.0102
# Epoch 453/500, Train Loss: 0.0039, Val Loss: 0.0101
# Epoch 454/500, Train Loss: 0.0040, Val Loss: 0.0101
# Epoch 455/500, Train Loss: 0.0041, Val Loss: 0.0102
# Epoch 456/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 457/500, Train Loss: 0.0040, Val Loss: 0.0101
# Epoch 458/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 459/500, Train Loss: 0.0041, Val Loss: 0.0101
# Epoch 460/500, Train Loss: 0.0041, Val Loss: 0.0102
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0018, max: 0.9577, mean: 0.1251, std: 0.1047
# Epoch 461/500, Train Loss: 0.0040, Val Loss: 0.0102
# Epoch 462/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 463/500, Train Loss: 0.0041, Val Loss: 0.0102
# Epoch 464/500, Train Loss: 0.0039, Val Loss: 0.0103
# Epoch 465/500, Train Loss: 0.0040, Val Loss: 0.0103
# Epoch 466/500, Train Loss: 0.0041, Val Loss: 0.0101
# Epoch 467/500, Train Loss: 0.0039, Val Loss: 0.0103
# Epoch 468/500, Train Loss: 0.0042, Val Loss: 0.0101
# Epoch 469/500, Train Loss: 0.0039, Val Loss: 0.0101
# Epoch 470/500, Train Loss: 0.0041, Val Loss: 0.0101
# Epoch 471/500, Train Loss: 0.0040, Val Loss: 0.0102
# Epoch 472/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 473/500, Train Loss: 0.0040, Val Loss: 0.0102
# Epoch 474/500, Train Loss: 0.0038, Val Loss: 0.0102
# Epoch 475/500, Train Loss: 0.0040, Val Loss: 0.0102
# Epoch 476/500, Train Loss: 0.0038, Val Loss: 0.0102
# Epoch 477/500, Train Loss: 0.0037, Val Loss: 0.0103
# Epoch 478/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 479/500, Train Loss: 0.0038, Val Loss: 0.0102
# Epoch 480/500, Train Loss: 0.0039, Val Loss: 0.0102
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0012, max: 0.9583, mean: 0.1233, std: 0.1042
# Epoch 481/500, Train Loss: 0.0038, Val Loss: 0.0103
# Epoch 482/500, Train Loss: 0.0041, Val Loss: 0.0103
# Epoch 483/500, Train Loss: 0.0040, Val Loss: 0.0104
# Epoch 484/500, Train Loss: 0.0042, Val Loss: 0.0103
# Epoch 485/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 486/500, Train Loss: 0.0038, Val Loss: 0.0102
# Epoch 487/500, Train Loss: 0.0042, Val Loss: 0.0102
# Epoch 488/500, Train Loss: 0.0042, Val Loss: 0.0102
# Epoch 489/500, Train Loss: 0.0040, Val Loss: 0.0103
# Epoch 490/500, Train Loss: 0.0038, Val Loss: 0.0102
# Epoch 491/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 492/500, Train Loss: 0.0039, Val Loss: 0.0102
# Epoch 493/500, Train Loss: 0.0037, Val Loss: 0.0103
# Epoch 494/500, Train Loss: 0.0037, Val Loss: 0.0103
# Epoch 495/500, Train Loss: 0.0037, Val Loss: 0.0103
# Epoch 496/500, Train Loss: 0.0038, Val Loss: 0.0104
# Epoch 497/500, Train Loss: 0.0036, Val Loss: 0.0104
# Epoch 498/500, Train Loss: 0.0037, Val Loss: 0.0104
# Epoch 499/500, Train Loss: 0.0037, Val Loss: 0.0104
# Epoch 500/500, Train Loss: 0.0037, Val Loss: 0.0104
# Input stats — min: 0.0000, max: 0.9412, mean: 0.1247, std: 0.1291
# Reconstruction stats — min: 0.0008, max: 0.9519, mean: 0.1254, std: 0.1061

# %%
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# Step 3: Cluster in Latent Space

def cluster_latents(model, dataloader, num_clusters=4):
    model.eval()
    latents = []
    images = []
    with torch.no_grad():
        for x, _ in dataloader:
            x = x.to(device)
            _, z = model(x)
            latents.append(z.cpu().numpy())
            images.append(x.cpu())
    latents = np.concatenate(latents, axis=0)
    images = torch.cat(images, dim=0)

    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(latents)
    labels = kmeans.labels_
    return latents, labels, images

# Step 4: Visualize Clusters with t-SNE and Reconstructed Images

def visualize_clusters(latents, labels, images, model):
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    latents_2d = tsne.fit_transform(latents)

    plt.figure(figsize=(8, 6))
    plt.scatter(latents_2d[:, 0], latents_2d[:, 1], c=labels, cmap='tab10', alpha=0.7, s=0.5)
    plt.xlabel("t-SNE Dimension 1")
    plt.ylabel("t-SNE Dimension 2")
    plt.title("2D Visualization of Latent Space using t-SNE")
    plt.show()

    selected_images = []
    selected_labels = set()
    for i, label in enumerate(labels):
        if label not in selected_labels:
            selected_labels.add(label)
            selected_images.append(images[i])
        if len(selected_labels) == 4:
            break

    selected_images = torch.stack(selected_images).to(device)
    reconstructed, _ = model(selected_images)

    fig, axes = plt.subplots(2, len(selected_images), figsize=(15, 5))
    for i in range(len(selected_images)):
        axes[0, i].imshow(selected_images[i].squeeze().cpu(), cmap='gray', vmax=1.0, vmin=0)
        axes[1, i].imshow(reconstructed[i].squeeze().cpu().detach(), cmap='gray', vmax=1.0, vmin=0)
        axes[0, i].axis('off')
        axes[1, i].axis('off')
    plt.show()

# %%
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE


# Step 5: Show multiple decoded images per cluster

def cluster_and_display_images(latents, labels, images, model, num_samples_per_cluster=10):
    unique_labels = np.unique(labels)
    fig, axes = plt.subplots(len(unique_labels)*2, num_samples_per_cluster, figsize=(num_samples_per_cluster*1.5, len(unique_labels)*2))

    for cluster_idx, cluster_label in enumerate(unique_labels):
        cluster_indices = np.where(labels == cluster_label)[0][:num_samples_per_cluster]
        cluster_images = images[cluster_indices].to(device)
        recon_images, _ = model(cluster_images)

        for i in range(num_samples_per_cluster):
            axes[2 * cluster_idx, i].imshow(cluster_images[i].squeeze().cpu(), cmap='gray', vmin=0, vmax=1.0)
            axes[2 * cluster_idx + 1, i].imshow(recon_images[i].squeeze().cpu().detach(), cmap='gray', vmin=0, vmax=1.0)
            axes[2 * cluster_idx, i].axis('off')
            axes[2 * cluster_idx + 1, i].axis('off')

    plt.tight_layout()
    plt.show()

# %%
latents, labels, images = cluster_latents(ae, train_loader, num_clusters=4)
# Out:
# /tmp/ipykernel_1134607/4152783461.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)

# %%
visualize_clusters(latents, labels, images, ae)

# %%
cluster_and_display_images(latents, labels, images, ae, num_samples_per_cluster=10)
