# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, random_split
import tifffile as tiff
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from PIL import Image

# Custom Dataset Loader for Unlabeled TIFF Images
class UnlabeledTIFFDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = [os.path.join(root_dir, fname) for fname in os.listdir(root_dir) if fname.lower().endswith(('tif', 'tiff'))]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        try:
            image = tiff.imread(img_path).astype(np.float32)   
            image = image * 240
            image[image > 254] = 254
            if image.ndim == 3:
                image = image[0]
            
        except Exception as e:
            print(f"Warning: Skipping unreadable image {img_path} - {e}")
            return self.__getitem__((idx + 1) % len(self.image_paths))

        image = image/255

        if self.transform:
            image = self.transform(image)

        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
        image = image.squeeze(1)
        return image, 0

# Step 1: Define a standard Autoencoder (AE)
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE


class AE(torch.nn.Module):
    def __init__(self, latent_dim=8):
        super(AE, self).__init__()
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 32, 3, stride=2, padding=1),  # 16 → 8
            torch.nn.BatchNorm2d(32),
            torch.nn.ReLU(),
            torch.nn.Conv2d(32, 64, 3, stride=2, padding=1),  # 8 → 4
            torch.nn.BatchNorm2d(64),
            torch.nn.ReLU(),
            torch.nn.Conv2d(64, 128, 3, stride=2, padding=1),  # 4 → 2
            torch.nn.BatchNorm2d(128),
            torch.nn.ReLU(),
            torch.nn.Flatten()
        )
        self.encoder_fc = torch.nn.Sequential(
            torch.nn.Linear(128 * 2 * 2, 512),  # From 128x2x2 = 512
            torch.nn.LeakyReLU(0.01),
            torch.nn.Dropout(p=0.1),
            torch.nn.Linear(512, latent_dim)
        )

        self.decoder_fc = torch.nn.Sequential(
            torch.nn.Linear(latent_dim, 512),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Dropout(p=0.1),
            torch.nn.Linear(512, 128 * 2 * 2)
        )

        self.decoder = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(128, 64, 3, stride=2, padding=1, output_padding=1),  # 2 → 4
            torch.nn.BatchNorm2d(64),
            torch.nn.LeakyReLU(0.01),
            torch.nn.ConvTranspose2d(64, 32, 3, stride=2, padding=1, output_padding=1),  # 4 → 8
            torch.nn.BatchNorm2d(32),
            torch.nn.LeakyReLU(0.01),
            torch.nn.ConvTranspose2d(32, 1, 3, stride=2, padding=1, output_padding=1),    # 8 → 16
            torch.nn.Sigmoid()
        )

    def encode(self, x):
        x = self.encoder(x)
        return self.encoder_fc(x)

    def decode(self, z):
        x = self.decoder_fc(z).view(-1, 128, 2, 2)
        return self.decoder(x)

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z), z


def plot_reconstruction_progress(model, dataloader, device, epoch):
    """Plot original vs reconstructed images during training"""
    model.eval()
    with torch.no_grad():
        for x, _ in dataloader:
            x = x.to(device)
            recon, _ = model(x)
            break  # only one batch

    x = x.cpu()
    recon = recon.cpu()

    print(f"Input stats — min: {x.min().item():.4f}, max: {x.max().item():.4f}, mean: {x.mean().item():.4f}, std: {x.std().item():.4f}")
    print(f"Reconstruction stats — min: {recon.min().item():.4f}, max: {recon.max().item():.4f}, mean: {recon.mean().item():.4f}, std: {recon.std().item():.4f}")

    n = min(8, x.size(0))
    fig, axes = plt.subplots(2, n, figsize=(n * 1, 2))
    for i in range(n):
        axes[0, i].imshow(x[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axes[0, i].axis("off")
        axes[1, i].imshow(recon[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axes[1, i].axis("off")
    plt.suptitle(f"Reconstruction at Epoch {epoch}")
    plt.tight_layout()
    plt.show()



# Step 2: Train Autoencoder and Extract Latent Representations
def train_ae(model, train_loader, val_loader, epochs=2000, lr=1e-4):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    train_losses, val_losses = [], []

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for x, _ in train_loader:
            x = x.to(device)
            recon, _ = model(x)
            loss = loss_fn(recon, x)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for x, _ in val_loader:
                x = x.to(device)
                recon, _ = model(x)
                loss = loss_fn(recon, x)
                val_loss += loss.item()
        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        if (epoch + 1) % 100 == 0:
            plot_reconstruction_progress(model, val_loader, device, epoch + 1)
            

    # Plot training and validation loss
    plt.plot(range(epochs), train_losses, label='Train Loss')
    plt.plot(range(epochs), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training vs Validation Loss')
    plt.show()

    return model


# Load Data
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_dir = '/mnt/d/lding/FA/analysis_results/FA_ML_Annabel_20250217/031125/ctrl_ch1_major/patches16_65p_20250606-1349'

transform = transforms.Compose([    
    transforms.ToTensor()
])
dataset = UnlabeledTIFFDataset(root_dir=data_dir, transform=transform)

# Split dataset into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# Train AE
ae = AE().to(device)
ae = train_ae(ae, train_loader, val_loader)

torch.save(ae.state_dict(), "ps16_bn_do_ae_weights_20250606.pth")
# Out:
# /tmp/ipykernel_1905662/814511437.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
# Epoch 1/2000, Train Loss: 0.1765, Val Loss: 0.1558
# Epoch 2/2000, Train Loss: 0.1318, Val Loss: 0.1434
# Epoch 3/2000, Train Loss: 0.1087, Val Loss: 0.1202
# Epoch 4/2000, Train Loss: 0.0935, Val Loss: 0.0957
# Epoch 5/2000, Train Loss: 0.0834, Val Loss: 0.0821
# Epoch 6/2000, Train Loss: 0.0752, Val Loss: 0.0729
# Epoch 7/2000, Train Loss: 0.0695, Val Loss: 0.0679
# Epoch 8/2000, Train Loss: 0.0623, Val Loss: 0.0611
# Epoch 9/2000, Train Loss: 0.0572, Val Loss: 0.0561
# Epoch 10/2000, Train Loss: 0.0533, Val Loss: 0.0528
# Epoch 11/2000, Train Loss: 0.0500, Val Loss: 0.0499
# Epoch 12/2000, Train Loss: 0.0467, Val Loss: 0.0467
# Epoch 13/2000, Train Loss: 0.0443, Val Loss: 0.0456
# Epoch 14/2000, Train Loss: 0.0418, Val Loss: 0.0427
# Epoch 15/2000, Train Loss: 0.0390, Val Loss: 0.0396
# Epoch 16/2000, Train Loss: 0.0373, Val Loss: 0.0375
# Epoch 17/2000, Train Loss: 0.0357, Val Loss: 0.0359
# Epoch 18/2000, Train Loss: 0.0381, Val Loss: 0.0385
# Epoch 19/2000, Train Loss: 0.0332, Val Loss: 0.0363
# Epoch 20/2000, Train Loss: 0.0338, Val Loss: 0.0380
# Epoch 21/2000, Train Loss: 0.0311, Val Loss: 0.0348
# Epoch 22/2000, Train Loss: 0.0295, Val Loss: 0.0298
# Epoch 23/2000, Train Loss: 0.0289, Val Loss: 0.0324
# Epoch 24/2000, Train Loss: 0.0274, Val Loss: 0.0286
# Epoch 25/2000, Train Loss: 0.0268, Val Loss: 0.0290
# Epoch 26/2000, Train Loss: 0.0261, Val Loss: 0.0285
# Epoch 27/2000, Train Loss: 0.0246, Val Loss: 0.0252
# Epoch 28/2000, Train Loss: 0.0240, Val Loss: 0.0265
# Epoch 29/2000, Train Loss: 0.0231, Val Loss: 0.0241
# Epoch 30/2000, Train Loss: 0.0232, Val Loss: 0.0268
# Epoch 31/2000, Train Loss: 0.0224, Val Loss: 0.0275
# Epoch 32/2000, Train Loss: 0.0215, Val Loss: 0.0219
# Epoch 33/2000, Train Loss: 0.0208, Val Loss: 0.0224
# Epoch 34/2000, Train Loss: 0.0200, Val Loss: 0.0217
# Epoch 35/2000, Train Loss: 0.0194, Val Loss: 0.0202
# Epoch 36/2000, Train Loss: 0.0190, Val Loss: 0.0201
# Epoch 37/2000, Train Loss: 0.0184, Val Loss: 0.0201
# Epoch 38/2000, Train Loss: 0.0180, Val Loss: 0.0191
# Epoch 39/2000, Train Loss: 0.0175, Val Loss: 0.0185
# Epoch 40/2000, Train Loss: 0.0192, Val Loss: 0.0226
# Epoch 41/2000, Train Loss: 0.0174, Val Loss: 0.0211
# Epoch 42/2000, Train Loss: 0.0167, Val Loss: 0.0187
# Epoch 43/2000, Train Loss: 0.0163, Val Loss: 0.0188
# Epoch 44/2000, Train Loss: 0.0159, Val Loss: 0.0192
# Epoch 45/2000, Train Loss: 0.0153, Val Loss: 0.0179
# Epoch 46/2000, Train Loss: 0.0146, Val Loss: 0.0156
# Epoch 47/2000, Train Loss: 0.0143, Val Loss: 0.0151
# Epoch 48/2000, Train Loss: 0.0141, Val Loss: 0.0157
# Epoch 49/2000, Train Loss: 0.0137, Val Loss: 0.0144
# Epoch 50/2000, Train Loss: 0.0144, Val Loss: 0.0166
# Epoch 51/2000, Train Loss: 0.0138, Val Loss: 0.0175
# Epoch 52/2000, Train Loss: 0.0134, Val Loss: 0.0145
# Epoch 53/2000, Train Loss: 0.0128, Val Loss: 0.0135
# Epoch 54/2000, Train Loss: 0.0129, Val Loss: 0.0156
# Epoch 55/2000, Train Loss: 0.0124, Val Loss: 0.0154
# Epoch 56/2000, Train Loss: 0.0119, Val Loss: 0.0135
# Epoch 57/2000, Train Loss: 0.0116, Val Loss: 0.0130
# Epoch 58/2000, Train Loss: 0.0113, Val Loss: 0.0120
# Epoch 59/2000, Train Loss: 0.0111, Val Loss: 0.0128
# Epoch 60/2000, Train Loss: 0.0108, Val Loss: 0.0122
# Epoch 61/2000, Train Loss: 0.0106, Val Loss: 0.0122
# Epoch 62/2000, Train Loss: 0.0103, Val Loss: 0.0116
# Epoch 63/2000, Train Loss: 0.0103, Val Loss: 0.0120
# Epoch 64/2000, Train Loss: 0.0100, Val Loss: 0.0119
# Epoch 65/2000, Train Loss: 0.0097, Val Loss: 0.0109
# Epoch 66/2000, Train Loss: 0.0096, Val Loss: 0.0107
# Epoch 67/2000, Train Loss: 0.0094, Val Loss: 0.0106
# Epoch 68/2000, Train Loss: 0.0098, Val Loss: 0.0122
# Epoch 69/2000, Train Loss: 0.0095, Val Loss: 0.0133
# Epoch 70/2000, Train Loss: 0.0094, Val Loss: 0.0111
# Epoch 71/2000, Train Loss: 0.0089, Val Loss: 0.0108
# Epoch 72/2000, Train Loss: 0.0087, Val Loss: 0.0100
# Epoch 73/2000, Train Loss: 0.0085, Val Loss: 0.0096
# Epoch 74/2000, Train Loss: 0.0084, Val Loss: 0.0094
# Epoch 75/2000, Train Loss: 0.0082, Val Loss: 0.0092
# Epoch 76/2000, Train Loss: 0.0081, Val Loss: 0.0089
# Epoch 77/2000, Train Loss: 0.0082, Val Loss: 0.0094
# Epoch 78/2000, Train Loss: 0.0078, Val Loss: 0.0090
# Epoch 79/2000, Train Loss: 0.0077, Val Loss: 0.0084
# Epoch 80/2000, Train Loss: 0.0075, Val Loss: 0.0086
# Epoch 81/2000, Train Loss: 0.0074, Val Loss: 0.0083
# Epoch 82/2000, Train Loss: 0.0073, Val Loss: 0.0082
# Epoch 83/2000, Train Loss: 0.0072, Val Loss: 0.0081
# Epoch 84/2000, Train Loss: 0.0071, Val Loss: 0.0078
# Epoch 85/2000, Train Loss: 0.0070, Val Loss: 0.0078
# Epoch 86/2000, Train Loss: 0.0069, Val Loss: 0.0079
# Epoch 87/2000, Train Loss: 0.0070, Val Loss: 0.0083
# Epoch 88/2000, Train Loss: 0.0068, Val Loss: 0.0082
# Epoch 89/2000, Train Loss: 0.0067, Val Loss: 0.0080
# Epoch 90/2000, Train Loss: 0.0066, Val Loss: 0.0077
# Epoch 91/2000, Train Loss: 0.0064, Val Loss: 0.0071
# Epoch 92/2000, Train Loss: 0.0073, Val Loss: 0.0081
# Epoch 93/2000, Train Loss: 0.0065, Val Loss: 0.0079
# Epoch 94/2000, Train Loss: 0.0064, Val Loss: 0.0068
# Epoch 95/2000, Train Loss: 0.0062, Val Loss: 0.0067
# Epoch 96/2000, Train Loss: 0.0060, Val Loss: 0.0066
# Epoch 97/2000, Train Loss: 0.0060, Val Loss: 0.0069
# Epoch 98/2000, Train Loss: 0.0059, Val Loss: 0.0073
# Epoch 99/2000, Train Loss: 0.0058, Val Loss: 0.0065
# Epoch 100/2000, Train Loss: 0.0059, Val Loss: 0.0068
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0085, max: 0.9998, mean: 0.1273, std: 0.0729
# Epoch 101/2000, Train Loss: 0.0061, Val Loss: 0.0074
# Epoch 102/2000, Train Loss: 0.0058, Val Loss: 0.0067
# Epoch 103/2000, Train Loss: 0.0060, Val Loss: 0.0068
# Epoch 104/2000, Train Loss: 0.0057, Val Loss: 0.0068
# Epoch 105/2000, Train Loss: 0.0054, Val Loss: 0.0060
# Epoch 106/2000, Train Loss: 0.0055, Val Loss: 0.0062
# Epoch 107/2000, Train Loss: 0.0053, Val Loss: 0.0063
# Epoch 108/2000, Train Loss: 0.0053, Val Loss: 0.0060
# Epoch 109/2000, Train Loss: 0.0053, Val Loss: 0.0063
# Epoch 110/2000, Train Loss: 0.0053, Val Loss: 0.0063
# Epoch 111/2000, Train Loss: 0.0051, Val Loss: 0.0060
# Epoch 112/2000, Train Loss: 0.0050, Val Loss: 0.0059
# Epoch 113/2000, Train Loss: 0.0049, Val Loss: 0.0056
# Epoch 114/2000, Train Loss: 0.0049, Val Loss: 0.0055
# Epoch 115/2000, Train Loss: 0.0048, Val Loss: 0.0056
# Epoch 116/2000, Train Loss: 0.0048, Val Loss: 0.0055
# Epoch 117/2000, Train Loss: 0.0048, Val Loss: 0.0054
# Epoch 118/2000, Train Loss: 0.0048, Val Loss: 0.0056
# Epoch 119/2000, Train Loss: 0.0047, Val Loss: 0.0052
# Epoch 120/2000, Train Loss: 0.0052, Val Loss: 0.0056
# Epoch 121/2000, Train Loss: 0.0048, Val Loss: 0.0058
# Epoch 122/2000, Train Loss: 0.0047, Val Loss: 0.0052
# Epoch 123/2000, Train Loss: 0.0047, Val Loss: 0.0050
# Epoch 124/2000, Train Loss: 0.0045, Val Loss: 0.0051
# Epoch 125/2000, Train Loss: 0.0045, Val Loss: 0.0049
# Epoch 126/2000, Train Loss: 0.0047, Val Loss: 0.0050
# Epoch 127/2000, Train Loss: 0.0045, Val Loss: 0.0051
# Epoch 128/2000, Train Loss: 0.0047, Val Loss: 0.0052
# Epoch 129/2000, Train Loss: 0.0045, Val Loss: 0.0049
# Epoch 130/2000, Train Loss: 0.0044, Val Loss: 0.0051
# Epoch 131/2000, Train Loss: 0.0043, Val Loss: 0.0048
# Epoch 132/2000, Train Loss: 0.0043, Val Loss: 0.0047
# Epoch 133/2000, Train Loss: 0.0044, Val Loss: 0.0048
# Epoch 134/2000, Train Loss: 0.0041, Val Loss: 0.0048
# Epoch 135/2000, Train Loss: 0.0041, Val Loss: 0.0049
# Epoch 136/2000, Train Loss: 0.0042, Val Loss: 0.0050
# Epoch 137/2000, Train Loss: 0.0040, Val Loss: 0.0047
# Epoch 138/2000, Train Loss: 0.0042, Val Loss: 0.0046
# Epoch 139/2000, Train Loss: 0.0040, Val Loss: 0.0046
# Epoch 140/2000, Train Loss: 0.0042, Val Loss: 0.0047
# Epoch 141/2000, Train Loss: 0.0043, Val Loss: 0.0049
# Epoch 142/2000, Train Loss: 0.0041, Val Loss: 0.0049
# Epoch 143/2000, Train Loss: 0.0039, Val Loss: 0.0044
# Epoch 144/2000, Train Loss: 0.0040, Val Loss: 0.0044
# Epoch 145/2000, Train Loss: 0.0042, Val Loss: 0.0049
# Epoch 146/2000, Train Loss: 0.0040, Val Loss: 0.0046
# Epoch 147/2000, Train Loss: 0.0038, Val Loss: 0.0044
# Epoch 148/2000, Train Loss: 0.0038, Val Loss: 0.0044
# Epoch 149/2000, Train Loss: 0.0039, Val Loss: 0.0045
# Epoch 150/2000, Train Loss: 0.0038, Val Loss: 0.0043
# Epoch 151/2000, Train Loss: 0.0037, Val Loss: 0.0041
# Epoch 152/2000, Train Loss: 0.0038, Val Loss: 0.0043
# Epoch 153/2000, Train Loss: 0.0037, Val Loss: 0.0043
# Epoch 154/2000, Train Loss: 0.0037, Val Loss: 0.0042
# Epoch 155/2000, Train Loss: 0.0038, Val Loss: 0.0042
# Epoch 156/2000, Train Loss: 0.0036, Val Loss: 0.0041
# Epoch 157/2000, Train Loss: 0.0036, Val Loss: 0.0041
# Epoch 158/2000, Train Loss: 0.0037, Val Loss: 0.0041
# Epoch 159/2000, Train Loss: 0.0036, Val Loss: 0.0041
# Epoch 160/2000, Train Loss: 0.0035, Val Loss: 0.0042
# Epoch 161/2000, Train Loss: 0.0037, Val Loss: 0.0042
# Epoch 162/2000, Train Loss: 0.0036, Val Loss: 0.0040
# Epoch 163/2000, Train Loss: 0.0035, Val Loss: 0.0040
# Epoch 164/2000, Train Loss: 0.0035, Val Loss: 0.0039
# Epoch 165/2000, Train Loss: 0.0036, Val Loss: 0.0040
# Epoch 166/2000, Train Loss: 0.0035, Val Loss: 0.0040
# Epoch 167/2000, Train Loss: 0.0035, Val Loss: 0.0040
# Epoch 168/2000, Train Loss: 0.0034, Val Loss: 0.0038
# Epoch 169/2000, Train Loss: 0.0035, Val Loss: 0.0038
# Epoch 170/2000, Train Loss: 0.0035, Val Loss: 0.0040
# Epoch 171/2000, Train Loss: 0.0033, Val Loss: 0.0040
# Epoch 172/2000, Train Loss: 0.0034, Val Loss: 0.0039
# Epoch 173/2000, Train Loss: 0.0033, Val Loss: 0.0039
# Epoch 174/2000, Train Loss: 0.0033, Val Loss: 0.0040
# Epoch 175/2000, Train Loss: 0.0034, Val Loss: 0.0040
# Epoch 176/2000, Train Loss: 0.0034, Val Loss: 0.0040
# Epoch 177/2000, Train Loss: 0.0034, Val Loss: 0.0039
# Epoch 178/2000, Train Loss: 0.0033, Val Loss: 0.0039
# Epoch 179/2000, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch 180/2000, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch 181/2000, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch 182/2000, Train Loss: 0.0032, Val Loss: 0.0036
# Epoch 183/2000, Train Loss: 0.0033, Val Loss: 0.0036
# Epoch 184/2000, Train Loss: 0.0033, Val Loss: 0.0038
# Epoch 185/2000, Train Loss: 0.0032, Val Loss: 0.0037
# Epoch 186/2000, Train Loss: 0.0032, Val Loss: 0.0036
# Epoch 187/2000, Train Loss: 0.0032, Val Loss: 0.0036
# Epoch 188/2000, Train Loss: 0.0032, Val Loss: 0.0036
# Epoch 189/2000, Train Loss: 0.0031, Val Loss: 0.0035
# Epoch 190/2000, Train Loss: 0.0031, Val Loss: 0.0035
# Epoch 191/2000, Train Loss: 0.0032, Val Loss: 0.0036
# Epoch 192/2000, Train Loss: 0.0031, Val Loss: 0.0035
# Epoch 193/2000, Train Loss: 0.0031, Val Loss: 0.0035
# Epoch 194/2000, Train Loss: 0.0030, Val Loss: 0.0034
# Epoch 195/2000, Train Loss: 0.0031, Val Loss: 0.0035
# Epoch 196/2000, Train Loss: 0.0031, Val Loss: 0.0036
# Epoch 197/2000, Train Loss: 0.0030, Val Loss: 0.0035
# Epoch 198/2000, Train Loss: 0.0030, Val Loss: 0.0034
# Epoch 199/2000, Train Loss: 0.0031, Val Loss: 0.0034
# Epoch 200/2000, Train Loss: 0.0030, Val Loss: 0.0035
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0054, max: 0.5237, mean: 0.0970, std: 0.0764
# Epoch 201/2000, Train Loss: 0.0030, Val Loss: 0.0034
# Epoch 202/2000, Train Loss: 0.0031, Val Loss: 0.0034
# Epoch 203/2000, Train Loss: 0.0031, Val Loss: 0.0035
# Epoch 204/2000, Train Loss: 0.0030, Val Loss: 0.0035
# Epoch 205/2000, Train Loss: 0.0030, Val Loss: 0.0034
# Epoch 206/2000, Train Loss: 0.0030, Val Loss: 0.0033
# Epoch 207/2000, Train Loss: 0.0029, Val Loss: 0.0034
# Epoch 208/2000, Train Loss: 0.0030, Val Loss: 0.0034
# Epoch 209/2000, Train Loss: 0.0029, Val Loss: 0.0035
# Epoch 210/2000, Train Loss: 0.0029, Val Loss: 0.0033
# Epoch 211/2000, Train Loss: 0.0030, Val Loss: 0.0035
# Epoch 212/2000, Train Loss: 0.0029, Val Loss: 0.0034
# Epoch 213/2000, Train Loss: 0.0029, Val Loss: 0.0033
# Epoch 214/2000, Train Loss: 0.0030, Val Loss: 0.0033
# Epoch 215/2000, Train Loss: 0.0029, Val Loss: 0.0034
# Epoch 216/2000, Train Loss: 0.0029, Val Loss: 0.0033
# Epoch 217/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 218/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 219/2000, Train Loss: 0.0029, Val Loss: 0.0033
# Epoch 220/2000, Train Loss: 0.0029, Val Loss: 0.0033
# Epoch 221/2000, Train Loss: 0.0029, Val Loss: 0.0033
# Epoch 222/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 223/2000, Train Loss: 0.0029, Val Loss: 0.0032
# Epoch 224/2000, Train Loss: 0.0028, Val Loss: 0.0032
# Epoch 225/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 226/2000, Train Loss: 0.0029, Val Loss: 0.0033
# Epoch 227/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 228/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 229/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 230/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 231/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 232/2000, Train Loss: 0.0028, Val Loss: 0.0032
# Epoch 233/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 234/2000, Train Loss: 0.0028, Val Loss: 0.0033
# Epoch 235/2000, Train Loss: 0.0028, Val Loss: 0.0032
# Epoch 236/2000, Train Loss: 0.0028, Val Loss: 0.0032
# Epoch 237/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 238/2000, Train Loss: 0.0028, Val Loss: 0.0032
# Epoch 239/2000, Train Loss: 0.0027, Val Loss: 0.0033
# Epoch 240/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 241/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 242/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 243/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 244/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 245/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 246/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 247/2000, Train Loss: 0.0027, Val Loss: 0.0031
# Epoch 248/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 249/2000, Train Loss: 0.0027, Val Loss: 0.0031
# Epoch 250/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 251/2000, Train Loss: 0.0027, Val Loss: 0.0031
# Epoch 252/2000, Train Loss: 0.0027, Val Loss: 0.0032
# Epoch 253/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 254/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 255/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 256/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 257/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 258/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 259/2000, Train Loss: 0.0027, Val Loss: 0.0031
# Epoch 260/2000, Train Loss: 0.0026, Val Loss: 0.0032
# Epoch 261/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 262/2000, Train Loss: 0.0027, Val Loss: 0.0031
# Epoch 263/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 264/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 265/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 266/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 267/2000, Train Loss: 0.0025, Val Loss: 0.0031
# Epoch 268/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 269/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 270/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 271/2000, Train Loss: 0.0026, Val Loss: 0.0030
# Epoch 272/2000, Train Loss: 0.0025, Val Loss: 0.0031
# Epoch 273/2000, Train Loss: 0.0025, Val Loss: 0.0030
# Epoch 274/2000, Train Loss: 0.0026, Val Loss: 0.0030
# Epoch 275/2000, Train Loss: 0.0026, Val Loss: 0.0031
# Epoch 276/2000, Train Loss: 0.0025, Val Loss: 0.0031
# Epoch 277/2000, Train Loss: 0.0025, Val Loss: 0.0030
# Epoch 278/2000, Train Loss: 0.0025, Val Loss: 0.0031
# Epoch 279/2000, Train Loss: 0.0025, Val Loss: 0.0030
# Epoch 280/2000, Train Loss: 0.0025, Val Loss: 0.0030
# Epoch 281/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 282/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 283/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 284/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 285/2000, Train Loss: 0.0025, Val Loss: 0.0030
# Epoch 286/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 287/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 288/2000, Train Loss: 0.0025, Val Loss: 0.0030
# Epoch 289/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 290/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 291/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 292/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 293/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 294/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 295/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 296/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 297/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 298/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 299/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 300/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0046, max: 0.5468, mean: 0.0913, std: 0.0823
# Epoch 301/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 302/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 303/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 304/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 305/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 306/2000, Train Loss: 0.0025, Val Loss: 0.0030
# Epoch 307/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 308/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 309/2000, Train Loss: 0.0024, Val Loss: 0.0030
# Epoch 310/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 311/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 312/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 313/2000, Train Loss: 0.0024, Val Loss: 0.0029
# Epoch 314/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 315/2000, Train Loss: 0.0024, Val Loss: 0.0029
# Epoch 316/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 317/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 318/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 319/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 320/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 321/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 322/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 323/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 324/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 325/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 326/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 327/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 328/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 329/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 330/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 331/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 332/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 333/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 334/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 335/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 336/2000, Train Loss: 0.0024, Val Loss: 0.0029
# Epoch 337/2000, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 338/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 339/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 340/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 341/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 342/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 343/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 344/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 345/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 346/2000, Train Loss: 0.0022, Val Loss: 0.0030
# Epoch 347/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 348/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 349/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 350/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 351/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 352/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 353/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 354/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 355/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 356/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 357/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 358/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 359/2000, Train Loss: 0.0022, Val Loss: 0.0030
# Epoch 360/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 361/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 362/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 363/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 364/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 365/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 366/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 367/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 368/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 369/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 370/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 371/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 372/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 373/2000, Train Loss: 0.0023, Val Loss: 0.0029
# Epoch 374/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 375/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 376/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 377/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 378/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 379/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 380/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 381/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 382/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 383/2000, Train Loss: 0.0021, Val Loss: 0.0030
# Epoch 384/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 385/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 386/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 387/2000, Train Loss: 0.0022, Val Loss: 0.0030
# Epoch 388/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 389/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 390/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 391/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 392/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 393/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 394/2000, Train Loss: 0.0022, Val Loss: 0.0029
# Epoch 395/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 396/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 397/2000, Train Loss: 0.0022, Val Loss: 0.0030
# Epoch 398/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 399/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 400/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0031, max: 0.5628, mean: 0.0853, std: 0.0805
# Epoch 401/2000, Train Loss: 0.0021, Val Loss: 0.0030
# Epoch 402/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 403/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 404/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 405/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 406/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 407/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 408/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 409/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 410/2000, Train Loss: 0.0021, Val Loss: 0.0030
# Epoch 411/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 412/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 413/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 414/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 415/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 416/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 417/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 418/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 419/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 420/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 421/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 422/2000, Train Loss: 0.0021, Val Loss: 0.0030
# Epoch 423/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 424/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 425/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 426/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 427/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 428/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 429/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 430/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 431/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 432/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 433/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 434/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 435/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 436/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 437/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 438/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 439/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 440/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 441/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 442/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 443/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 444/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 445/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 446/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 447/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 448/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 449/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 450/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 451/2000, Train Loss: 0.0020, Val Loss: 0.0030
# Epoch 452/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 453/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 454/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 455/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 456/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 457/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 458/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 459/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 460/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 461/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 462/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 463/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 464/2000, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 465/2000, Train Loss: 0.0021, Val Loss: 0.0030
# Epoch 466/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 467/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 468/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 469/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 470/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 471/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 472/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 473/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 474/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 475/2000, Train Loss: 0.0020, Val Loss: 0.0030
# Epoch 476/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 477/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 478/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 479/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 480/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 481/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 482/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 483/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 484/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 485/2000, Train Loss: 0.0020, Val Loss: 0.0030
# Epoch 486/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 487/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 488/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 489/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 490/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 491/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 492/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 493/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 494/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 495/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 496/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 497/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 498/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 499/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 500/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0025, max: 0.6379, mean: 0.0870, std: 0.0837
# Epoch 501/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 502/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 503/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 504/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 505/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 506/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 507/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 508/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 509/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 510/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 511/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 512/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 513/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 514/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 515/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 516/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 517/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 518/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 519/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 520/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 521/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 522/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 523/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 524/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 525/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 526/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 527/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 528/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 529/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 530/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 531/2000, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 532/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 533/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 534/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 535/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 536/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 537/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 538/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 539/2000, Train Loss: 0.0020, Val Loss: 0.0030
# Epoch 540/2000, Train Loss: 0.0020, Val Loss: 0.0030
# Epoch 541/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 542/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 543/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 544/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 545/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 546/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 547/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 548/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 549/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 550/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 551/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 552/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 553/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 554/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 555/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 556/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 557/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 558/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 559/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 560/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 561/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 562/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 563/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 564/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 565/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 566/2000, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 567/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 568/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 569/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 570/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 571/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 572/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 573/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 574/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 575/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 576/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 577/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 578/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 579/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 580/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 581/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 582/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 583/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 584/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 585/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 586/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 587/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 588/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 589/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 590/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 591/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 592/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 593/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 594/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 595/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 596/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 597/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 598/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 599/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 600/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0028, max: 0.6683, mean: 0.0854, std: 0.0827
# Epoch 601/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 602/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 603/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 604/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 605/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 606/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 607/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 608/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 609/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 610/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 611/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 612/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 613/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 614/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 615/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 616/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 617/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 618/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 619/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 620/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 621/2000, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 622/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 623/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 624/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 625/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 626/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 627/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 628/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 629/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 630/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 631/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 632/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 633/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 634/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 635/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 636/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 637/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 638/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 639/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 640/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 641/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 642/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 643/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 644/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 645/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 646/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 647/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 648/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 649/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 650/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 651/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 652/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 653/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 654/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 655/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 656/2000, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 657/2000, Train Loss: 0.0019, Val Loss: 0.0030
# Epoch 658/2000, Train Loss: 0.0018, Val Loss: 0.0031
# Epoch 659/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 660/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 661/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 662/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 663/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 664/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 665/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 666/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 667/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 668/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 669/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 670/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 671/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 672/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 673/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 674/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 675/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 676/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 677/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 678/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 679/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 680/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 681/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 682/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 683/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 684/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 685/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 686/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 687/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 688/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 689/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 690/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 691/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 692/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 693/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 694/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 695/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 696/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 697/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 698/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 699/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 700/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0023, max: 0.6595, mean: 0.0846, std: 0.0837
# Epoch 701/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 702/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 703/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 704/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 705/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 706/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 707/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 708/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 709/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 710/2000, Train Loss: 0.0016, Val Loss: 0.0030
# Epoch 711/2000, Train Loss: 0.0016, Val Loss: 0.0030
# Epoch 712/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 713/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 714/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 715/2000, Train Loss: 0.0016, Val Loss: 0.0030
# Epoch 716/2000, Train Loss: 0.0016, Val Loss: 0.0030
# Epoch 717/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 718/2000, Train Loss: 0.0017, Val Loss: 0.0030
# Epoch 719/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 720/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 721/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 722/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 723/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 724/2000, Train Loss: 0.0016, Val Loss: 0.0030
# Epoch 725/2000, Train Loss: 0.0016, Val Loss: 0.0030
# Epoch 726/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 727/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 728/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 729/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 730/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 731/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 732/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 733/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 734/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 735/2000, Train Loss: 0.0016, Val Loss: 0.0030
# Epoch 736/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 737/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 738/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 739/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 740/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 741/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 742/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 743/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 744/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 745/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 746/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 747/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 748/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 749/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 750/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 751/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 752/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 753/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 754/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 755/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 756/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 757/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 758/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 759/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 760/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 761/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 762/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 763/2000, Train Loss: 0.0016, Val Loss: 0.0032
# Epoch 764/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 765/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 766/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 767/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 768/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 769/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 770/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 771/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 772/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 773/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 774/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 775/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 776/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 777/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 778/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 779/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 780/2000, Train Loss: 0.0017, Val Loss: 0.0031
# Epoch 781/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 782/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 783/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 784/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 785/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 786/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 787/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 788/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 789/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 790/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 791/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 792/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 793/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 794/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 795/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 796/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 797/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 798/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 799/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 800/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0027, max: 0.6469, mean: 0.0857, std: 0.0842
# Epoch 801/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 802/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 803/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 804/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 805/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 806/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 807/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 808/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 809/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 810/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 811/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 812/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 813/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 814/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 815/2000, Train Loss: 0.0016, Val Loss: 0.0032
# Epoch 816/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 817/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 818/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 819/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 820/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 821/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 822/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 823/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 824/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 825/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 826/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 827/2000, Train Loss: 0.0016, Val Loss: 0.0031
# Epoch 828/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 829/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 830/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 831/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 832/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 833/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 834/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 835/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 836/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 837/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 838/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 839/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 840/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 841/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 842/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 843/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 844/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 845/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 846/2000, Train Loss: 0.0016, Val Loss: 0.0032
# Epoch 847/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 848/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 849/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 850/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 851/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 852/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 853/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 854/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 855/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 856/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 857/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 858/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 859/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 860/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 861/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 862/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 863/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 864/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 865/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 866/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 867/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 868/2000, Train Loss: 0.0016, Val Loss: 0.0032
# Epoch 869/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 870/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 871/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 872/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 873/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 874/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 875/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 876/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 877/2000, Train Loss: 0.0015, Val Loss: 0.0032
# Epoch 878/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 879/2000, Train Loss: 0.0015, Val Loss: 0.0031
# Epoch 880/2000, Train Loss: 0.0015, Val Loss: 0.0032
# ...
# Epoch 1713/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1714/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1715/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1716/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1717/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1718/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1719/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1720/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1721/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1722/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1723/2000, Train Loss: 0.0011, Val Loss: 0.0035
# Epoch 1724/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1725/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1726/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1727/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1728/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1729/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1730/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1731/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1732/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1733/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1734/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1735/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1736/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1737/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1738/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1739/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1740/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1741/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1742/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1743/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1744/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1745/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1746/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1747/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1748/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1749/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1750/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1751/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1752/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1753/2000, Train Loss: 0.0011, Val Loss: 0.0036
# Epoch 1754/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1755/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1756/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1757/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1758/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1759/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1760/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1761/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1762/2000, Train Loss: 0.0011, Val Loss: 0.0036
# Epoch 1763/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1764/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1765/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1766/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1767/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1768/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1769/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1770/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1771/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1772/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1773/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1774/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1775/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1776/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1777/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1778/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1779/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1780/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1781/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1782/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1783/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1784/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1785/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1786/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1787/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1788/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1789/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1790/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1791/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1792/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1793/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1794/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1795/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1796/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1797/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1798/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1799/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1800/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0012, max: 0.5643, mean: 0.0834, std: 0.0807
# Epoch 1801/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1802/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1803/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1804/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1805/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1806/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1807/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1808/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1809/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1810/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1811/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1812/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1813/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1814/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1815/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1816/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1817/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1818/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1819/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1820/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1821/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1822/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1823/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1824/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1825/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1826/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1827/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1828/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1829/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1830/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1831/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1832/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1833/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1834/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1835/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1836/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1837/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1838/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1839/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1840/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1841/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1842/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1843/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1844/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1845/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1846/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1847/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1848/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1849/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1850/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1851/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1852/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1853/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1854/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1855/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1856/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1857/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1858/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1859/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1860/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1861/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1862/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1863/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1864/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1865/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1866/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1867/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1868/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1869/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1870/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1871/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1872/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1873/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1874/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1875/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1876/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1877/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1878/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1879/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1880/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1881/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1882/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1883/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1884/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1885/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1886/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1887/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1888/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1889/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1890/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1891/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1892/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1893/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1894/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1895/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1896/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1897/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1898/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1899/2000, Train Loss: 0.0010, Val Loss: 0.0035
# Epoch 1900/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0008, max: 0.5743, mean: 0.0838, std: 0.0813
# Epoch 1901/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1902/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1903/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1904/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1905/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1906/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1907/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1908/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1909/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1910/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1911/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1912/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1913/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1914/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1915/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1916/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1917/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1918/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1919/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1920/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1921/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1922/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1923/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1924/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1925/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1926/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1927/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1928/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1929/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1930/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1931/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1932/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1933/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1934/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1935/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1936/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1937/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1938/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1939/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1940/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1941/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1942/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1943/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1944/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1945/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1946/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1947/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1948/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1949/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1950/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1951/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1952/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1953/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1954/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1955/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1956/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1957/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1958/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1959/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1960/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1961/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1962/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1963/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1964/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1965/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1966/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1967/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1968/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1969/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1970/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1971/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1972/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1973/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1974/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1975/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1976/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1977/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1978/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1979/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1980/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1981/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1982/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1983/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1984/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1985/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1986/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1987/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1988/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1989/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1990/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1991/2000, Train Loss: 0.0010, Val Loss: 0.0038
# Epoch 1992/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1993/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1994/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 1995/2000, Train Loss: 0.0009, Val Loss: 0.0036
# Epoch 1996/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1997/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Epoch 1998/2000, Train Loss: 0.0009, Val Loss: 0.0037
# Epoch 1999/2000, Train Loss: 0.0010, Val Loss: 0.0036
# Epoch 2000/2000, Train Loss: 0.0010, Val Loss: 0.0037
# Input stats — min: 0.0000, max: 0.8786, mean: 0.0857, std: 0.0968
# Reconstruction stats — min: 0.0009, max: 0.5732, mean: 0.0845, std: 0.0790

# %%
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# Step 3: Cluster in Latent Space

def cluster_latents(model, dataloader, num_clusters=4):
    model.eval()
    latents = []
    images = []
    with torch.no_grad():
        for x, _ in dataloader:
            x = x.to(device)
            _, z = model(x)
            latents.append(z.cpu().numpy())
            images.append(x.cpu())
    latents = np.concatenate(latents, axis=0)
    images = torch.cat(images, dim=0)

    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(latents)
    labels = kmeans.labels_
    return latents, labels, images

# Step 4: Visualize Clusters with t-SNE and Reconstructed Images

def visualize_clusters(latents, labels, images, model):
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    latents_2d = tsne.fit_transform(latents)

    plt.figure(figsize=(8, 6))
    plt.scatter(latents_2d[:, 0], latents_2d[:, 1], c=labels, cmap='tab10', alpha=0.7, s=0.5)
    plt.xlabel("t-SNE Dimension 1")
    plt.ylabel("t-SNE Dimension 2")
    plt.title("2D Visualization of Latent Space using t-SNE")
    plt.show()

    selected_images = []
    selected_labels = set()
    for i, label in enumerate(labels):
        if label not in selected_labels:
            selected_labels.add(label)
            selected_images.append(images[i])
        if len(selected_labels) == 4:
            break

    selected_images = torch.stack(selected_images).to(device)
    reconstructed, _ = model(selected_images)

    fig, axes = plt.subplots(2, len(selected_images), figsize=(15, 5))
    for i in range(len(selected_images)):
        axes[0, i].imshow(selected_images[i].squeeze().cpu(), cmap='gray', vmax=1.0, vmin=0)
        axes[1, i].imshow(reconstructed[i].squeeze().cpu().detach(), cmap='gray', vmax=1.0, vmin=0)
        axes[0, i].axis('off')
        axes[1, i].axis('off')
    plt.show()

# %%
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE


# Step 5: Show multiple decoded images per cluster

def cluster_and_display_images(latents, labels, images, model, num_samples_per_cluster=10):
    unique_labels = np.unique(labels)
    fig, axes = plt.subplots(len(unique_labels)*2, num_samples_per_cluster, figsize=(num_samples_per_cluster*1.5, len(unique_labels)*2))

    for cluster_idx, cluster_label in enumerate(unique_labels):
        cluster_indices = np.where(labels == cluster_label)[0][:num_samples_per_cluster]
        cluster_images = images[cluster_indices].to(device)
        recon_images, _ = model(cluster_images)

        for i in range(num_samples_per_cluster):
            axes[2 * cluster_idx, i].imshow(cluster_images[i].squeeze().cpu(), cmap='gray', vmin=0, vmax=1.0)
            axes[2 * cluster_idx + 1, i].imshow(recon_images[i].squeeze().cpu().detach(), cmap='gray', vmin=0, vmax=1.0)
            axes[2 * cluster_idx, i].axis('off')
            axes[2 * cluster_idx + 1, i].axis('off')

    plt.tight_layout()
    plt.show()

# %%
latents, labels, images = cluster_latents(ae, train_loader, num_clusters=4)
# Out:
# /tmp/ipykernel_1905662/814511437.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)

# %%
visualize_clusters(latents, labels, images, ae)

# %%
cluster_and_display_images(latents, labels, images, ae, num_samples_per_cluster=10)
