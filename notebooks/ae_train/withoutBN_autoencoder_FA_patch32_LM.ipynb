# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, random_split
import tifffile as tiff
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from PIL import Image

# Custom Dataset Loader for Unlabeled TIFF Images
class UnlabeledTIFFDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = [os.path.join(root_dir, fname) for fname in os.listdir(root_dir) if fname.lower().endswith(('tif', 'tiff'))]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        try:
            image = tiff.imread(img_path).astype(np.float32)   
            image = image * 240
            image[image > 254] = 254
            if image.ndim == 3:
                image = image[0]
            
        except Exception as e:
            print(f"Warning: Skipping unreadable image {img_path} - {e}")
            return self.__getitem__((idx + 1) % len(self.image_paths))

        image = image/255

        if self.transform:
            image = self.transform(image)

        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
        image = image.squeeze(1)
        return image, 0

# Step 1: Define a standard Autoencoder (AE)
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE


class AE(torch.nn.Module):
    def __init__(self, latent_dim=8):
        super(AE, self).__init__()
        self.encoder = torch.nn.Sequential(
            torch.nn.Conv2d(1, 32, 3, stride=2, padding=1),  # 32 -> 16
            torch.nn.LeakyReLU(0.01),
            torch.nn.Conv2d(32, 64, 3, stride=2, padding=1),  # 16 -> 8
            torch.nn.LeakyReLU(0.01),
            torch.nn.Conv2d(64, 128, 3, stride=2, padding=1),  # 8 -> 4
            torch.nn.LeakyReLU(0.01),
            torch.nn.Flatten()
        )
        self.encoder_fc = torch.nn.Sequential(
            torch.nn.Linear(128 * 4 * 4, 1024),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Linear(1024, latent_dim)
        )

        self.decoder_fc = torch.nn.Sequential(
            torch.nn.Linear(latent_dim, 1024),
            torch.nn.LeakyReLU(0.01),
            torch.nn.Linear(1024, 128 * 4 * 4)
        )

        self.decoder = torch.nn.Sequential(
            torch.nn.ConvTranspose2d(128, 64, 3, stride=2, padding=1, output_padding=1),  # 4 -> 8
            torch.nn.LeakyReLU(0.01),
            torch.nn.ConvTranspose2d(64, 32, 3, stride=2, padding=1, output_padding=1),  # 8 -> 16
            torch.nn.LeakyReLU(0.01),
            torch.nn.ConvTranspose2d(32, 1, 3, stride=2, padding=1, output_padding=1),   # 16 -> 32
            torch.nn.Sigmoid()
        )

    def encode(self, x):
        x = self.encoder(x)
        return self.encoder_fc(x)

    def decode(self, z):
        x = self.decoder_fc(z).view(-1, 128, 4, 4)
        return self.decoder(x)

    def forward(self, x):
        z = self.encode(x)
        return self.decode(z), z

def plot_reconstruction_progress(model, dataloader, device, epoch):
    """Plot original vs reconstructed images during training"""
    model.eval()
    with torch.no_grad():
        for x, _ in dataloader:
            x = x.to(device)
            recon, _ = model(x)
            break  # only one batch

    x = x.cpu()
    recon = recon.cpu()

    print(f"Input stats — min: {x.min().item():.4f}, max: {x.max().item():.4f}, mean: {x.mean().item():.4f}, std: {x.std().item():.4f}")
    print(f"Reconstruction stats — min: {recon.min().item():.4f}, max: {recon.max().item():.4f}, mean: {recon.mean().item():.4f}, std: {recon.std().item():.4f}")

    n = min(8, x.size(0))
    fig, axes = plt.subplots(2, n, figsize=(n * 1, 2))
    for i in range(n):
        axes[0, i].imshow(x[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axes[0, i].axis("off")
        axes[1, i].imshow(recon[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axes[1, i].axis("off")
    plt.suptitle(f"Reconstruction at Epoch {epoch}")
    plt.tight_layout()
    plt.show()



# Step 2: Train Autoencoder and Extract Latent Representations
def train_ae(model, train_loader, val_loader, epochs=500, lr=1e-4):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
    train_losses, val_losses = [], []

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        for x, _ in train_loader:
            x = x.to(device)
            recon, _ = model(x)
            loss = loss_fn(recon, x)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for x, _ in val_loader:
                x = x.to(device)
                recon, _ = model(x)
                loss = loss_fn(recon, x)
                val_loss += loss.item()
        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")

        if (epoch + 1) % 20 == 0:
            plot_reconstruction_progress(model, val_loader, device, epoch + 1)
            

    # Plot training and validation loss
    plt.plot(range(epochs), train_losses, label='Train Loss')
    plt.plot(range(epochs), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training vs Validation Loss')
    plt.show()

    return model


# Load Data
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_dir = '/mnt/d/lding/FA/analysis_results/FA_ML_Annabel_20250217/031125data/ctrl_ch1_major/localmax_patches32_65p_20250827-1149'
transform = transforms.Compose([    
    transforms.ToTensor()
])
dataset = UnlabeledTIFFDataset(root_dir=data_dir, transform=transform)

# Split dataset into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# Train AE
ae = AE().to(device)
ae = train_ae(ae, train_loader, val_loader)
# Out:
# /tmp/ipykernel_2940993/1666222699.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
# Epoch 1/500, Train Loss: 0.1226, Val Loss: 0.1166
# Epoch 2/500, Train Loss: 0.1019, Val Loss: 0.0736
# Epoch 3/500, Train Loss: 0.0577, Val Loss: 0.0503
# Epoch 4/500, Train Loss: 0.0471, Val Loss: 0.0432
# Epoch 5/500, Train Loss: 0.0408, Val Loss: 0.0375
# Epoch 6/500, Train Loss: 0.0354, Val Loss: 0.0328
# Epoch 7/500, Train Loss: 0.0311, Val Loss: 0.0285
# Epoch 8/500, Train Loss: 0.0268, Val Loss: 0.0251
# Epoch 9/500, Train Loss: 0.0249, Val Loss: 0.0244
# Epoch 10/500, Train Loss: 0.0248, Val Loss: 0.0241
# Epoch 11/500, Train Loss: 0.0239, Val Loss: 0.0239
# Epoch 12/500, Train Loss: 0.0236, Val Loss: 0.0237
# Epoch 13/500, Train Loss: 0.0236, Val Loss: 0.0233
# Epoch 14/500, Train Loss: 0.0231, Val Loss: 0.0227
# Epoch 15/500, Train Loss: 0.0223, Val Loss: 0.0216
# Epoch 16/500, Train Loss: 0.0204, Val Loss: 0.0196
# Epoch 17/500, Train Loss: 0.0188, Val Loss: 0.0189
# Epoch 18/500, Train Loss: 0.0180, Val Loss: 0.0182
# Epoch 19/500, Train Loss: 0.0175, Val Loss: 0.0176
# Epoch 20/500, Train Loss: 0.0169, Val Loss: 0.0167
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0174, max: 0.9252, mean: 0.1804, std: 0.1164
# Epoch 21/500, Train Loss: 0.0162, Val Loss: 0.0160
# Epoch 22/500, Train Loss: 0.0157, Val Loss: 0.0156
# Epoch 23/500, Train Loss: 0.0151, Val Loss: 0.0151
# Epoch 24/500, Train Loss: 0.0146, Val Loss: 0.0148
# Epoch 25/500, Train Loss: 0.0144, Val Loss: 0.0146
# Epoch 26/500, Train Loss: 0.0145, Val Loss: 0.0145
# Epoch 27/500, Train Loss: 0.0141, Val Loss: 0.0144
# Epoch 28/500, Train Loss: 0.0138, Val Loss: 0.0143
# Epoch 29/500, Train Loss: 0.0139, Val Loss: 0.0141
# Epoch 30/500, Train Loss: 0.0137, Val Loss: 0.0140
# Epoch 31/500, Train Loss: 0.0134, Val Loss: 0.0139
# Epoch 32/500, Train Loss: 0.0133, Val Loss: 0.0138
# Epoch 33/500, Train Loss: 0.0132, Val Loss: 0.0137
# Epoch 34/500, Train Loss: 0.0129, Val Loss: 0.0136
# Epoch 35/500, Train Loss: 0.0129, Val Loss: 0.0135
# Epoch 36/500, Train Loss: 0.0127, Val Loss: 0.0134
# Epoch 37/500, Train Loss: 0.0126, Val Loss: 0.0132
# Epoch 38/500, Train Loss: 0.0125, Val Loss: 0.0131
# Epoch 39/500, Train Loss: 0.0123, Val Loss: 0.0131
# Epoch 40/500, Train Loss: 0.0124, Val Loss: 0.0130
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0140, max: 0.9411, mean: 0.1765, std: 0.1366
# Epoch 41/500, Train Loss: 0.0121, Val Loss: 0.0130
# Epoch 42/500, Train Loss: 0.0119, Val Loss: 0.0129
# Epoch 43/500, Train Loss: 0.0122, Val Loss: 0.0129
# Epoch 44/500, Train Loss: 0.0120, Val Loss: 0.0129
# Epoch 45/500, Train Loss: 0.0121, Val Loss: 0.0129
# Epoch 46/500, Train Loss: 0.0120, Val Loss: 0.0128
# Epoch 47/500, Train Loss: 0.0118, Val Loss: 0.0128
# Epoch 48/500, Train Loss: 0.0120, Val Loss: 0.0128
# Epoch 49/500, Train Loss: 0.0118, Val Loss: 0.0128
# Epoch 50/500, Train Loss: 0.0119, Val Loss: 0.0127
# Epoch 51/500, Train Loss: 0.0117, Val Loss: 0.0128
# Epoch 52/500, Train Loss: 0.0117, Val Loss: 0.0127
# Epoch 53/500, Train Loss: 0.0115, Val Loss: 0.0127
# Epoch 54/500, Train Loss: 0.0116, Val Loss: 0.0127
# Epoch 55/500, Train Loss: 0.0115, Val Loss: 0.0127
# Epoch 56/500, Train Loss: 0.0116, Val Loss: 0.0127
# Epoch 57/500, Train Loss: 0.0115, Val Loss: 0.0127
# Epoch 58/500, Train Loss: 0.0114, Val Loss: 0.0127
# Epoch 59/500, Train Loss: 0.0114, Val Loss: 0.0126
# Epoch 60/500, Train Loss: 0.0114, Val Loss: 0.0126
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0115, max: 0.9351, mean: 0.1798, std: 0.1396
# Epoch 61/500, Train Loss: 0.0114, Val Loss: 0.0127
# Epoch 62/500, Train Loss: 0.0112, Val Loss: 0.0127
# Epoch 63/500, Train Loss: 0.0111, Val Loss: 0.0127
# Epoch 64/500, Train Loss: 0.0112, Val Loss: 0.0126
# Epoch 65/500, Train Loss: 0.0112, Val Loss: 0.0127
# Epoch 66/500, Train Loss: 0.0111, Val Loss: 0.0127
# Epoch 67/500, Train Loss: 0.0110, Val Loss: 0.0127
# Epoch 68/500, Train Loss: 0.0111, Val Loss: 0.0126
# Epoch 69/500, Train Loss: 0.0111, Val Loss: 0.0127
# Epoch 70/500, Train Loss: 0.0111, Val Loss: 0.0126
# Epoch 71/500, Train Loss: 0.0109, Val Loss: 0.0127
# Epoch 72/500, Train Loss: 0.0110, Val Loss: 0.0127
# Epoch 73/500, Train Loss: 0.0109, Val Loss: 0.0126
# Epoch 74/500, Train Loss: 0.0107, Val Loss: 0.0127
# Epoch 75/500, Train Loss: 0.0108, Val Loss: 0.0127
# Epoch 76/500, Train Loss: 0.0108, Val Loss: 0.0127
# Epoch 77/500, Train Loss: 0.0107, Val Loss: 0.0127
# Epoch 78/500, Train Loss: 0.0107, Val Loss: 0.0127
# Epoch 79/500, Train Loss: 0.0106, Val Loss: 0.0127
# Epoch 80/500, Train Loss: 0.0109, Val Loss: 0.0128
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0130, max: 0.9479, mean: 0.1833, std: 0.1437
# Epoch 81/500, Train Loss: 0.0106, Val Loss: 0.0127
# Epoch 82/500, Train Loss: 0.0107, Val Loss: 0.0128
# Epoch 83/500, Train Loss: 0.0106, Val Loss: 0.0128
# Epoch 84/500, Train Loss: 0.0106, Val Loss: 0.0128
# Epoch 85/500, Train Loss: 0.0106, Val Loss: 0.0127
# Epoch 86/500, Train Loss: 0.0106, Val Loss: 0.0128
# Epoch 87/500, Train Loss: 0.0105, Val Loss: 0.0128
# Epoch 88/500, Train Loss: 0.0104, Val Loss: 0.0128
# Epoch 89/500, Train Loss: 0.0103, Val Loss: 0.0128
# Epoch 90/500, Train Loss: 0.0105, Val Loss: 0.0128
# Epoch 91/500, Train Loss: 0.0104, Val Loss: 0.0128
# Epoch 92/500, Train Loss: 0.0104, Val Loss: 0.0128
# Epoch 93/500, Train Loss: 0.0103, Val Loss: 0.0128
# Epoch 94/500, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch 95/500, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch 96/500, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch 97/500, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch 98/500, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch 99/500, Train Loss: 0.0102, Val Loss: 0.0129
# Epoch 100/500, Train Loss: 0.0100, Val Loss: 0.0130
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0118, max: 0.9592, mean: 0.1829, std: 0.1445
# Epoch 101/500, Train Loss: 0.0099, Val Loss: 0.0129
# Epoch 102/500, Train Loss: 0.0100, Val Loss: 0.0130
# Epoch 103/500, Train Loss: 0.0098, Val Loss: 0.0130
# Epoch 104/500, Train Loss: 0.0099, Val Loss: 0.0130
# Epoch 105/500, Train Loss: 0.0099, Val Loss: 0.0130
# Epoch 106/500, Train Loss: 0.0098, Val Loss: 0.0130
# Epoch 107/500, Train Loss: 0.0100, Val Loss: 0.0130
# Epoch 108/500, Train Loss: 0.0100, Val Loss: 0.0132
# Epoch 109/500, Train Loss: 0.0098, Val Loss: 0.0131
# Epoch 110/500, Train Loss: 0.0097, Val Loss: 0.0131
# Epoch 111/500, Train Loss: 0.0096, Val Loss: 0.0131
# Epoch 112/500, Train Loss: 0.0096, Val Loss: 0.0131
# Epoch 113/500, Train Loss: 0.0096, Val Loss: 0.0131
# Epoch 114/500, Train Loss: 0.0096, Val Loss: 0.0131
# Epoch 115/500, Train Loss: 0.0096, Val Loss: 0.0131
# Epoch 116/500, Train Loss: 0.0095, Val Loss: 0.0131
# Epoch 117/500, Train Loss: 0.0095, Val Loss: 0.0131
# Epoch 118/500, Train Loss: 0.0094, Val Loss: 0.0132
# Epoch 119/500, Train Loss: 0.0094, Val Loss: 0.0132
# Epoch 120/500, Train Loss: 0.0094, Val Loss: 0.0133
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0083, max: 0.9782, mean: 0.1809, std: 0.1464
# Epoch 121/500, Train Loss: 0.0093, Val Loss: 0.0132
# Epoch 122/500, Train Loss: 0.0093, Val Loss: 0.0133
# Epoch 123/500, Train Loss: 0.0093, Val Loss: 0.0133
# Epoch 124/500, Train Loss: 0.0094, Val Loss: 0.0134
# Epoch 125/500, Train Loss: 0.0093, Val Loss: 0.0134
# Epoch 126/500, Train Loss: 0.0092, Val Loss: 0.0134
# Epoch 127/500, Train Loss: 0.0091, Val Loss: 0.0134
# Epoch 128/500, Train Loss: 0.0090, Val Loss: 0.0134
# Epoch 129/500, Train Loss: 0.0091, Val Loss: 0.0134
# Epoch 130/500, Train Loss: 0.0092, Val Loss: 0.0135
# Epoch 131/500, Train Loss: 0.0091, Val Loss: 0.0134
# Epoch 132/500, Train Loss: 0.0090, Val Loss: 0.0135
# Epoch 133/500, Train Loss: 0.0090, Val Loss: 0.0136
# Epoch 134/500, Train Loss: 0.0089, Val Loss: 0.0135
# Epoch 135/500, Train Loss: 0.0090, Val Loss: 0.0135
# Epoch 136/500, Train Loss: 0.0090, Val Loss: 0.0136
# Epoch 137/500, Train Loss: 0.0089, Val Loss: 0.0137
# Epoch 138/500, Train Loss: 0.0089, Val Loss: 0.0135
# Epoch 139/500, Train Loss: 0.0089, Val Loss: 0.0137
# Epoch 140/500, Train Loss: 0.0089, Val Loss: 0.0137
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0098, max: 0.9858, mean: 0.1819, std: 0.1488
# Epoch 141/500, Train Loss: 0.0087, Val Loss: 0.0137
# Epoch 142/500, Train Loss: 0.0087, Val Loss: 0.0136
# Epoch 143/500, Train Loss: 0.0086, Val Loss: 0.0137
# Epoch 144/500, Train Loss: 0.0087, Val Loss: 0.0137
# Epoch 145/500, Train Loss: 0.0087, Val Loss: 0.0137
# Epoch 146/500, Train Loss: 0.0086, Val Loss: 0.0138
# Epoch 147/500, Train Loss: 0.0086, Val Loss: 0.0139
# Epoch 148/500, Train Loss: 0.0085, Val Loss: 0.0139
# Epoch 149/500, Train Loss: 0.0085, Val Loss: 0.0138
# Epoch 150/500, Train Loss: 0.0085, Val Loss: 0.0138
# Epoch 151/500, Train Loss: 0.0086, Val Loss: 0.0138
# Epoch 152/500, Train Loss: 0.0084, Val Loss: 0.0138
# Epoch 153/500, Train Loss: 0.0083, Val Loss: 0.0139
# Epoch 154/500, Train Loss: 0.0083, Val Loss: 0.0139
# Epoch 155/500, Train Loss: 0.0083, Val Loss: 0.0139
# Epoch 156/500, Train Loss: 0.0083, Val Loss: 0.0140
# Epoch 157/500, Train Loss: 0.0083, Val Loss: 0.0140
# Epoch 158/500, Train Loss: 0.0082, Val Loss: 0.0142
# Epoch 159/500, Train Loss: 0.0082, Val Loss: 0.0140
# Epoch 160/500, Train Loss: 0.0082, Val Loss: 0.0141
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0095, max: 0.9815, mean: 0.1819, std: 0.1504
# Epoch 161/500, Train Loss: 0.0082, Val Loss: 0.0141
# Epoch 162/500, Train Loss: 0.0082, Val Loss: 0.0141
# Epoch 163/500, Train Loss: 0.0081, Val Loss: 0.0142
# Epoch 164/500, Train Loss: 0.0080, Val Loss: 0.0142
# Epoch 165/500, Train Loss: 0.0081, Val Loss: 0.0142
# Epoch 166/500, Train Loss: 0.0080, Val Loss: 0.0142
# Epoch 167/500, Train Loss: 0.0080, Val Loss: 0.0142
# Epoch 168/500, Train Loss: 0.0079, Val Loss: 0.0142
# Epoch 169/500, Train Loss: 0.0079, Val Loss: 0.0144
# Epoch 170/500, Train Loss: 0.0080, Val Loss: 0.0144
# Epoch 171/500, Train Loss: 0.0080, Val Loss: 0.0142
# Epoch 172/500, Train Loss: 0.0079, Val Loss: 0.0143
# Epoch 173/500, Train Loss: 0.0079, Val Loss: 0.0143
# Epoch 174/500, Train Loss: 0.0079, Val Loss: 0.0144
# Epoch 175/500, Train Loss: 0.0078, Val Loss: 0.0143
# Epoch 176/500, Train Loss: 0.0078, Val Loss: 0.0143
# Epoch 177/500, Train Loss: 0.0076, Val Loss: 0.0144
# Epoch 178/500, Train Loss: 0.0077, Val Loss: 0.0144
# Epoch 179/500, Train Loss: 0.0077, Val Loss: 0.0145
# Epoch 180/500, Train Loss: 0.0077, Val Loss: 0.0145
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0091, max: 0.9866, mean: 0.1802, std: 0.1529
# Epoch 181/500, Train Loss: 0.0077, Val Loss: 0.0144
# Epoch 182/500, Train Loss: 0.0077, Val Loss: 0.0146
# Epoch 183/500, Train Loss: 0.0075, Val Loss: 0.0146
# Epoch 184/500, Train Loss: 0.0075, Val Loss: 0.0146
# Epoch 185/500, Train Loss: 0.0076, Val Loss: 0.0144
# Epoch 186/500, Train Loss: 0.0075, Val Loss: 0.0147
# Epoch 187/500, Train Loss: 0.0075, Val Loss: 0.0146
# Epoch 188/500, Train Loss: 0.0076, Val Loss: 0.0146
# Epoch 189/500, Train Loss: 0.0075, Val Loss: 0.0149
# Epoch 190/500, Train Loss: 0.0075, Val Loss: 0.0145
# Epoch 191/500, Train Loss: 0.0074, Val Loss: 0.0147
# Epoch 192/500, Train Loss: 0.0073, Val Loss: 0.0147
# Epoch 193/500, Train Loss: 0.0073, Val Loss: 0.0147
# Epoch 194/500, Train Loss: 0.0073, Val Loss: 0.0148
# Epoch 195/500, Train Loss: 0.0072, Val Loss: 0.0148
# Epoch 196/500, Train Loss: 0.0072, Val Loss: 0.0147
# Epoch 197/500, Train Loss: 0.0073, Val Loss: 0.0149
# Epoch 198/500, Train Loss: 0.0072, Val Loss: 0.0149
# Epoch 199/500, Train Loss: 0.0072, Val Loss: 0.0148
# Epoch 200/500, Train Loss: 0.0072, Val Loss: 0.0149
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0084, max: 0.9876, mean: 0.1797, std: 0.1532
# Epoch 201/500, Train Loss: 0.0072, Val Loss: 0.0149
# Epoch 202/500, Train Loss: 0.0072, Val Loss: 0.0148
# Epoch 203/500, Train Loss: 0.0072, Val Loss: 0.0150
# Epoch 204/500, Train Loss: 0.0071, Val Loss: 0.0150
# Epoch 205/500, Train Loss: 0.0072, Val Loss: 0.0150
# Epoch 206/500, Train Loss: 0.0070, Val Loss: 0.0149
# Epoch 207/500, Train Loss: 0.0071, Val Loss: 0.0149
# Epoch 208/500, Train Loss: 0.0070, Val Loss: 0.0149
# Epoch 209/500, Train Loss: 0.0070, Val Loss: 0.0150
# Epoch 210/500, Train Loss: 0.0070, Val Loss: 0.0150
# Epoch 211/500, Train Loss: 0.0069, Val Loss: 0.0152
# Epoch 212/500, Train Loss: 0.0070, Val Loss: 0.0151
# Epoch 213/500, Train Loss: 0.0069, Val Loss: 0.0152
# Epoch 214/500, Train Loss: 0.0069, Val Loss: 0.0150
# Epoch 215/500, Train Loss: 0.0068, Val Loss: 0.0152
# Epoch 216/500, Train Loss: 0.0069, Val Loss: 0.0151
# Epoch 217/500, Train Loss: 0.0068, Val Loss: 0.0151
# Epoch 218/500, Train Loss: 0.0067, Val Loss: 0.0152
# Epoch 219/500, Train Loss: 0.0068, Val Loss: 0.0152
# Epoch 220/500, Train Loss: 0.0067, Val Loss: 0.0152
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0089, max: 0.9953, mean: 0.1797, std: 0.1531
# Epoch 221/500, Train Loss: 0.0067, Val Loss: 0.0153
# Epoch 222/500, Train Loss: 0.0067, Val Loss: 0.0152
# Epoch 223/500, Train Loss: 0.0067, Val Loss: 0.0153
# Epoch 224/500, Train Loss: 0.0066, Val Loss: 0.0153
# Epoch 225/500, Train Loss: 0.0067, Val Loss: 0.0152
# Epoch 226/500, Train Loss: 0.0067, Val Loss: 0.0153
# Epoch 227/500, Train Loss: 0.0067, Val Loss: 0.0153
# Epoch 228/500, Train Loss: 0.0066, Val Loss: 0.0155
# Epoch 229/500, Train Loss: 0.0067, Val Loss: 0.0156
# Epoch 230/500, Train Loss: 0.0066, Val Loss: 0.0154
# Epoch 231/500, Train Loss: 0.0066, Val Loss: 0.0155
# Epoch 232/500, Train Loss: 0.0066, Val Loss: 0.0154
# Epoch 233/500, Train Loss: 0.0065, Val Loss: 0.0155
# Epoch 234/500, Train Loss: 0.0065, Val Loss: 0.0155
# Epoch 235/500, Train Loss: 0.0064, Val Loss: 0.0154
# Epoch 236/500, Train Loss: 0.0064, Val Loss: 0.0155
# Epoch 237/500, Train Loss: 0.0064, Val Loss: 0.0156
# Epoch 238/500, Train Loss: 0.0064, Val Loss: 0.0156
# Epoch 239/500, Train Loss: 0.0065, Val Loss: 0.0155
# Epoch 240/500, Train Loss: 0.0065, Val Loss: 0.0155
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0090, max: 0.9934, mean: 0.1779, std: 0.1525
# Epoch 241/500, Train Loss: 0.0064, Val Loss: 0.0156
# Epoch 242/500, Train Loss: 0.0064, Val Loss: 0.0157
# Epoch 243/500, Train Loss: 0.0065, Val Loss: 0.0157
# Epoch 244/500, Train Loss: 0.0064, Val Loss: 0.0155
# Epoch 245/500, Train Loss: 0.0063, Val Loss: 0.0156
# Epoch 246/500, Train Loss: 0.0063, Val Loss: 0.0157
# Epoch 247/500, Train Loss: 0.0063, Val Loss: 0.0157
# Epoch 248/500, Train Loss: 0.0063, Val Loss: 0.0156
# Epoch 249/500, Train Loss: 0.0062, Val Loss: 0.0157
# Epoch 250/500, Train Loss: 0.0062, Val Loss: 0.0156
# Epoch 251/500, Train Loss: 0.0062, Val Loss: 0.0157
# Epoch 252/500, Train Loss: 0.0062, Val Loss: 0.0157
# Epoch 253/500, Train Loss: 0.0062, Val Loss: 0.0156
# Epoch 254/500, Train Loss: 0.0062, Val Loss: 0.0158
# Epoch 255/500, Train Loss: 0.0061, Val Loss: 0.0158
# Epoch 256/500, Train Loss: 0.0062, Val Loss: 0.0158
# Epoch 257/500, Train Loss: 0.0061, Val Loss: 0.0158
# Epoch 258/500, Train Loss: 0.0061, Val Loss: 0.0158
# Epoch 259/500, Train Loss: 0.0061, Val Loss: 0.0160
# Epoch 260/500, Train Loss: 0.0061, Val Loss: 0.0158
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0071, max: 0.9969, mean: 0.1780, std: 0.1547
# Epoch 261/500, Train Loss: 0.0062, Val Loss: 0.0159
# Epoch 262/500, Train Loss: 0.0061, Val Loss: 0.0159
# Epoch 263/500, Train Loss: 0.0061, Val Loss: 0.0160
# Epoch 264/500, Train Loss: 0.0061, Val Loss: 0.0158
# Epoch 265/500, Train Loss: 0.0061, Val Loss: 0.0158
# Epoch 266/500, Train Loss: 0.0060, Val Loss: 0.0159
# Epoch 267/500, Train Loss: 0.0060, Val Loss: 0.0159
# Epoch 268/500, Train Loss: 0.0060, Val Loss: 0.0158
# Epoch 269/500, Train Loss: 0.0060, Val Loss: 0.0158
# Epoch 270/500, Train Loss: 0.0060, Val Loss: 0.0160
# Epoch 271/500, Train Loss: 0.0059, Val Loss: 0.0160
# Epoch 272/500, Train Loss: 0.0059, Val Loss: 0.0160
# Epoch 273/500, Train Loss: 0.0060, Val Loss: 0.0160
# Epoch 274/500, Train Loss: 0.0059, Val Loss: 0.0161
# Epoch 275/500, Train Loss: 0.0059, Val Loss: 0.0159
# Epoch 276/500, Train Loss: 0.0058, Val Loss: 0.0161
# Epoch 277/500, Train Loss: 0.0058, Val Loss: 0.0161
# Epoch 278/500, Train Loss: 0.0058, Val Loss: 0.0163
# Epoch 279/500, Train Loss: 0.0058, Val Loss: 0.0161
# Epoch 280/500, Train Loss: 0.0058, Val Loss: 0.0161
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0064, max: 0.9965, mean: 0.1816, std: 0.1566
# Epoch 281/500, Train Loss: 0.0057, Val Loss: 0.0161
# Epoch 282/500, Train Loss: 0.0058, Val Loss: 0.0161
# Epoch 283/500, Train Loss: 0.0057, Val Loss: 0.0162
# Epoch 284/500, Train Loss: 0.0057, Val Loss: 0.0163
# Epoch 285/500, Train Loss: 0.0057, Val Loss: 0.0162
# Epoch 286/500, Train Loss: 0.0057, Val Loss: 0.0162
# Epoch 287/500, Train Loss: 0.0056, Val Loss: 0.0161
# Epoch 288/500, Train Loss: 0.0058, Val Loss: 0.0162
# Epoch 289/500, Train Loss: 0.0056, Val Loss: 0.0161
# Epoch 290/500, Train Loss: 0.0056, Val Loss: 0.0163
# Epoch 291/500, Train Loss: 0.0057, Val Loss: 0.0163
# Epoch 292/500, Train Loss: 0.0057, Val Loss: 0.0162
# Epoch 293/500, Train Loss: 0.0056, Val Loss: 0.0164
# Epoch 294/500, Train Loss: 0.0055, Val Loss: 0.0165
# Epoch 295/500, Train Loss: 0.0056, Val Loss: 0.0165
# Epoch 296/500, Train Loss: 0.0056, Val Loss: 0.0165
# Epoch 297/500, Train Loss: 0.0056, Val Loss: 0.0165
# Epoch 298/500, Train Loss: 0.0055, Val Loss: 0.0163
# Epoch 299/500, Train Loss: 0.0056, Val Loss: 0.0164
# Epoch 300/500, Train Loss: 0.0055, Val Loss: 0.0165
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0048, max: 0.9959, mean: 0.1832, std: 0.1578
# Epoch 301/500, Train Loss: 0.0056, Val Loss: 0.0165
# Epoch 302/500, Train Loss: 0.0056, Val Loss: 0.0165
# Epoch 303/500, Train Loss: 0.0056, Val Loss: 0.0166
# Epoch 304/500, Train Loss: 0.0056, Val Loss: 0.0166
# Epoch 305/500, Train Loss: 0.0055, Val Loss: 0.0166
# Epoch 306/500, Train Loss: 0.0055, Val Loss: 0.0164
# Epoch 307/500, Train Loss: 0.0055, Val Loss: 0.0165
# Epoch 308/500, Train Loss: 0.0055, Val Loss: 0.0163
# Epoch 309/500, Train Loss: 0.0054, Val Loss: 0.0164
# Epoch 310/500, Train Loss: 0.0054, Val Loss: 0.0164
# Epoch 311/500, Train Loss: 0.0055, Val Loss: 0.0165
# Epoch 312/500, Train Loss: 0.0054, Val Loss: 0.0166
# Epoch 313/500, Train Loss: 0.0054, Val Loss: 0.0165
# Epoch 314/500, Train Loss: 0.0054, Val Loss: 0.0164
# Epoch 315/500, Train Loss: 0.0054, Val Loss: 0.0165
# Epoch 316/500, Train Loss: 0.0054, Val Loss: 0.0165
# Epoch 317/500, Train Loss: 0.0053, Val Loss: 0.0165
# Epoch 318/500, Train Loss: 0.0053, Val Loss: 0.0168
# Epoch 319/500, Train Loss: 0.0053, Val Loss: 0.0167
# Epoch 320/500, Train Loss: 0.0053, Val Loss: 0.0166
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0056, max: 0.9965, mean: 0.1802, std: 0.1572
# Epoch 321/500, Train Loss: 0.0053, Val Loss: 0.0164
# Epoch 322/500, Train Loss: 0.0053, Val Loss: 0.0164
# Epoch 323/500, Train Loss: 0.0053, Val Loss: 0.0167
# Epoch 324/500, Train Loss: 0.0053, Val Loss: 0.0166
# Epoch 325/500, Train Loss: 0.0053, Val Loss: 0.0167
# Epoch 326/500, Train Loss: 0.0052, Val Loss: 0.0168
# Epoch 327/500, Train Loss: 0.0053, Val Loss: 0.0168
# Epoch 328/500, Train Loss: 0.0052, Val Loss: 0.0168
# Epoch 329/500, Train Loss: 0.0053, Val Loss: 0.0166
# Epoch 330/500, Train Loss: 0.0052, Val Loss: 0.0165
# Epoch 331/500, Train Loss: 0.0052, Val Loss: 0.0167
# Epoch 332/500, Train Loss: 0.0051, Val Loss: 0.0168
# Epoch 333/500, Train Loss: 0.0052, Val Loss: 0.0169
# Epoch 334/500, Train Loss: 0.0052, Val Loss: 0.0167
# Epoch 335/500, Train Loss: 0.0052, Val Loss: 0.0167
# Epoch 336/500, Train Loss: 0.0051, Val Loss: 0.0167
# Epoch 337/500, Train Loss: 0.0051, Val Loss: 0.0168
# Epoch 338/500, Train Loss: 0.0051, Val Loss: 0.0167
# Epoch 339/500, Train Loss: 0.0051, Val Loss: 0.0168
# Epoch 340/500, Train Loss: 0.0052, Val Loss: 0.0168
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0057, max: 0.9984, mean: 0.1813, std: 0.1589
# Epoch 341/500, Train Loss: 0.0051, Val Loss: 0.0170
# Epoch 342/500, Train Loss: 0.0051, Val Loss: 0.0168
# Epoch 343/500, Train Loss: 0.0051, Val Loss: 0.0169
# Epoch 344/500, Train Loss: 0.0051, Val Loss: 0.0169
# Epoch 345/500, Train Loss: 0.0052, Val Loss: 0.0169
# Epoch 346/500, Train Loss: 0.0050, Val Loss: 0.0170
# Epoch 347/500, Train Loss: 0.0050, Val Loss: 0.0168
# Epoch 348/500, Train Loss: 0.0050, Val Loss: 0.0170
# Epoch 349/500, Train Loss: 0.0050, Val Loss: 0.0168
# Epoch 350/500, Train Loss: 0.0050, Val Loss: 0.0168
# Epoch 351/500, Train Loss: 0.0050, Val Loss: 0.0168
# Epoch 352/500, Train Loss: 0.0051, Val Loss: 0.0166
# Epoch 353/500, Train Loss: 0.0050, Val Loss: 0.0168
# Epoch 354/500, Train Loss: 0.0050, Val Loss: 0.0170
# Epoch 355/500, Train Loss: 0.0050, Val Loss: 0.0170
# Epoch 356/500, Train Loss: 0.0050, Val Loss: 0.0169
# Epoch 357/500, Train Loss: 0.0049, Val Loss: 0.0171
# Epoch 358/500, Train Loss: 0.0049, Val Loss: 0.0171
# Epoch 359/500, Train Loss: 0.0049, Val Loss: 0.0169
# Epoch 360/500, Train Loss: 0.0049, Val Loss: 0.0169
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0059, max: 0.9988, mean: 0.1784, std: 0.1600
# Epoch 361/500, Train Loss: 0.0049, Val Loss: 0.0169
# Epoch 362/500, Train Loss: 0.0048, Val Loss: 0.0168
# Epoch 363/500, Train Loss: 0.0049, Val Loss: 0.0168
# Epoch 364/500, Train Loss: 0.0049, Val Loss: 0.0169
# Epoch 365/500, Train Loss: 0.0048, Val Loss: 0.0170
# Epoch 366/500, Train Loss: 0.0048, Val Loss: 0.0169
# Epoch 367/500, Train Loss: 0.0048, Val Loss: 0.0172
# Epoch 368/500, Train Loss: 0.0048, Val Loss: 0.0170
# Epoch 369/500, Train Loss: 0.0048, Val Loss: 0.0169
# Epoch 370/500, Train Loss: 0.0049, Val Loss: 0.0170
# Epoch 371/500, Train Loss: 0.0048, Val Loss: 0.0170
# Epoch 372/500, Train Loss: 0.0048, Val Loss: 0.0170
# Epoch 373/500, Train Loss: 0.0048, Val Loss: 0.0171
# Epoch 374/500, Train Loss: 0.0048, Val Loss: 0.0173
# Epoch 375/500, Train Loss: 0.0048, Val Loss: 0.0171
# Epoch 376/500, Train Loss: 0.0048, Val Loss: 0.0169
# Epoch 377/500, Train Loss: 0.0048, Val Loss: 0.0170
# Epoch 378/500, Train Loss: 0.0048, Val Loss: 0.0170
# Epoch 379/500, Train Loss: 0.0047, Val Loss: 0.0171
# Epoch 380/500, Train Loss: 0.0048, Val Loss: 0.0170
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0039, max: 0.9984, mean: 0.1781, std: 0.1603
# Epoch 381/500, Train Loss: 0.0047, Val Loss: 0.0171
# Epoch 382/500, Train Loss: 0.0047, Val Loss: 0.0170
# Epoch 383/500, Train Loss: 0.0047, Val Loss: 0.0171
# Epoch 384/500, Train Loss: 0.0047, Val Loss: 0.0171
# Epoch 385/500, Train Loss: 0.0047, Val Loss: 0.0174
# Epoch 386/500, Train Loss: 0.0047, Val Loss: 0.0173
# Epoch 387/500, Train Loss: 0.0046, Val Loss: 0.0174
# Epoch 388/500, Train Loss: 0.0047, Val Loss: 0.0171
# Epoch 389/500, Train Loss: 0.0047, Val Loss: 0.0171
# Epoch 390/500, Train Loss: 0.0046, Val Loss: 0.0171
# Epoch 391/500, Train Loss: 0.0046, Val Loss: 0.0171
# Epoch 392/500, Train Loss: 0.0046, Val Loss: 0.0173
# Epoch 393/500, Train Loss: 0.0047, Val Loss: 0.0173
# Epoch 394/500, Train Loss: 0.0047, Val Loss: 0.0174
# Epoch 395/500, Train Loss: 0.0046, Val Loss: 0.0173
# Epoch 396/500, Train Loss: 0.0047, Val Loss: 0.0173
# Epoch 397/500, Train Loss: 0.0046, Val Loss: 0.0173
# Epoch 398/500, Train Loss: 0.0046, Val Loss: 0.0171
# Epoch 399/500, Train Loss: 0.0046, Val Loss: 0.0173
# Epoch 400/500, Train Loss: 0.0046, Val Loss: 0.0172
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0046, max: 0.9975, mean: 0.1810, std: 0.1605
# Epoch 401/500, Train Loss: 0.0046, Val Loss: 0.0172
# Epoch 402/500, Train Loss: 0.0045, Val Loss: 0.0172
# Epoch 403/500, Train Loss: 0.0046, Val Loss: 0.0173
# Epoch 404/500, Train Loss: 0.0046, Val Loss: 0.0173
# Epoch 405/500, Train Loss: 0.0045, Val Loss: 0.0174
# Epoch 406/500, Train Loss: 0.0045, Val Loss: 0.0173
# Epoch 407/500, Train Loss: 0.0045, Val Loss: 0.0173
# Epoch 408/500, Train Loss: 0.0045, Val Loss: 0.0171
# Epoch 409/500, Train Loss: 0.0045, Val Loss: 0.0174
# Epoch 410/500, Train Loss: 0.0045, Val Loss: 0.0174
# Epoch 411/500, Train Loss: 0.0045, Val Loss: 0.0174
# Epoch 412/500, Train Loss: 0.0045, Val Loss: 0.0172
# Epoch 413/500, Train Loss: 0.0045, Val Loss: 0.0172
# Epoch 414/500, Train Loss: 0.0045, Val Loss: 0.0172
# Epoch 415/500, Train Loss: 0.0045, Val Loss: 0.0173
# Epoch 416/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 417/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 418/500, Train Loss: 0.0044, Val Loss: 0.0173
# Epoch 419/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 420/500, Train Loss: 0.0044, Val Loss: 0.0173
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0038, max: 0.9977, mean: 0.1750, std: 0.1588
# Epoch 421/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 422/500, Train Loss: 0.0044, Val Loss: 0.0173
# Epoch 423/500, Train Loss: 0.0044, Val Loss: 0.0173
# Epoch 424/500, Train Loss: 0.0044, Val Loss: 0.0175
# Epoch 425/500, Train Loss: 0.0044, Val Loss: 0.0175
# Epoch 426/500, Train Loss: 0.0044, Val Loss: 0.0172
# Epoch 427/500, Train Loss: 0.0045, Val Loss: 0.0174
# Epoch 428/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 429/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 430/500, Train Loss: 0.0044, Val Loss: 0.0175
# Epoch 431/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 432/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 433/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 434/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 435/500, Train Loss: 0.0044, Val Loss: 0.0174
# Epoch 436/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 437/500, Train Loss: 0.0043, Val Loss: 0.0174
# Epoch 438/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 439/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 440/500, Train Loss: 0.0043, Val Loss: 0.0175
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0037, max: 0.9979, mean: 0.1819, std: 0.1618
# Epoch 441/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 442/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 443/500, Train Loss: 0.0042, Val Loss: 0.0174
# Epoch 444/500, Train Loss: 0.0043, Val Loss: 0.0174
# Epoch 445/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 446/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 447/500, Train Loss: 0.0042, Val Loss: 0.0175
# Epoch 448/500, Train Loss: 0.0042, Val Loss: 0.0176
# Epoch 449/500, Train Loss: 0.0042, Val Loss: 0.0175
# Epoch 450/500, Train Loss: 0.0043, Val Loss: 0.0175
# Epoch 451/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 452/500, Train Loss: 0.0042, Val Loss: 0.0176
# Epoch 453/500, Train Loss: 0.0042, Val Loss: 0.0176
# Epoch 454/500, Train Loss: 0.0042, Val Loss: 0.0175
# Epoch 455/500, Train Loss: 0.0042, Val Loss: 0.0176
# Epoch 456/500, Train Loss: 0.0042, Val Loss: 0.0178
# Epoch 457/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 458/500, Train Loss: 0.0042, Val Loss: 0.0176
# Epoch 459/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 460/500, Train Loss: 0.0042, Val Loss: 0.0175
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0031, max: 0.9987, mean: 0.1749, std: 0.1593
# Epoch 461/500, Train Loss: 0.0042, Val Loss: 0.0175
# Epoch 462/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 463/500, Train Loss: 0.0042, Val Loss: 0.0176
# Epoch 464/500, Train Loss: 0.0041, Val Loss: 0.0175
# Epoch 465/500, Train Loss: 0.0041, Val Loss: 0.0176
# Epoch 466/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 467/500, Train Loss: 0.0041, Val Loss: 0.0176
# Epoch 468/500, Train Loss: 0.0041, Val Loss: 0.0174
# Epoch 469/500, Train Loss: 0.0042, Val Loss: 0.0175
# Epoch 470/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 471/500, Train Loss: 0.0042, Val Loss: 0.0179
# Epoch 472/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 473/500, Train Loss: 0.0042, Val Loss: 0.0175
# Epoch 474/500, Train Loss: 0.0041, Val Loss: 0.0176
# Epoch 475/500, Train Loss: 0.0041, Val Loss: 0.0178
# Epoch 476/500, Train Loss: 0.0041, Val Loss: 0.0175
# Epoch 477/500, Train Loss: 0.0041, Val Loss: 0.0177
# Epoch 478/500, Train Loss: 0.0041, Val Loss: 0.0179
# Epoch 479/500, Train Loss: 0.0041, Val Loss: 0.0177
# Epoch 480/500, Train Loss: 0.0041, Val Loss: 0.0177
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0032, max: 0.9986, mean: 0.1793, std: 0.1629
# Epoch 481/500, Train Loss: 0.0041, Val Loss: 0.0176
# Epoch 482/500, Train Loss: 0.0041, Val Loss: 0.0180
# Epoch 483/500, Train Loss: 0.0041, Val Loss: 0.0177
# Epoch 484/500, Train Loss: 0.0042, Val Loss: 0.0177
# Epoch 485/500, Train Loss: 0.0041, Val Loss: 0.0176
# Epoch 486/500, Train Loss: 0.0041, Val Loss: 0.0177
# Epoch 487/500, Train Loss: 0.0040, Val Loss: 0.0178
# Epoch 488/500, Train Loss: 0.0040, Val Loss: 0.0177
# Epoch 489/500, Train Loss: 0.0040, Val Loss: 0.0175
# Epoch 490/500, Train Loss: 0.0040, Val Loss: 0.0178
# Epoch 491/500, Train Loss: 0.0039, Val Loss: 0.0177
# Epoch 492/500, Train Loss: 0.0040, Val Loss: 0.0177
# Epoch 493/500, Train Loss: 0.0040, Val Loss: 0.0178
# Epoch 494/500, Train Loss: 0.0040, Val Loss: 0.0179
# Epoch 495/500, Train Loss: 0.0040, Val Loss: 0.0178
# Epoch 496/500, Train Loss: 0.0040, Val Loss: 0.0178
# Epoch 497/500, Train Loss: 0.0040, Val Loss: 0.0179
# Epoch 498/500, Train Loss: 0.0040, Val Loss: 0.0178
# Epoch 499/500, Train Loss: 0.0040, Val Loss: 0.0178
# Epoch 500/500, Train Loss: 0.0040, Val Loss: 0.0178
# Input stats — min: 0.0000, max: 0.9486, mean: 0.1803, std: 0.1815
# Reconstruction stats — min: 0.0026, max: 0.9976, mean: 0.1775, std: 0.1620

# %%
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# Step 3: Cluster in Latent Space

def cluster_latents(model, dataloader, num_clusters=4):
    model.eval()
    latents = []
    images = []
    with torch.no_grad():
        for x, _ in dataloader:
            x = x.to(device)
            _, z = model(x)
            latents.append(z.cpu().numpy())
            images.append(x.cpu())
    latents = np.concatenate(latents, axis=0)
    images = torch.cat(images, dim=0)

    kmeans = KMeans(n_clusters=num_clusters, random_state=0).fit(latents)
    labels = kmeans.labels_
    return latents, labels, images

# Step 4: Visualize Clusters with t-SNE and Reconstructed Images

def visualize_clusters(latents, labels, images, model):
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    latents_2d = tsne.fit_transform(latents)

    plt.figure(figsize=(8, 6))
    plt.scatter(latents_2d[:, 0], latents_2d[:, 1], c=labels, cmap='tab10', alpha=0.7, s=0.5)
    plt.xlabel("t-SNE Dimension 1")
    plt.ylabel("t-SNE Dimension 2")
    plt.title("2D Visualization of Latent Space using t-SNE")
    plt.show()

    selected_images = []
    selected_labels = set()
    for i, label in enumerate(labels):
        if label not in selected_labels:
            selected_labels.add(label)
            selected_images.append(images[i])
        if len(selected_labels) == 4:
            break

    selected_images = torch.stack(selected_images).to(device)
    reconstructed, _ = model(selected_images)

    fig, axes = plt.subplots(2, len(selected_images), figsize=(15, 5))
    for i in range(len(selected_images)):
        axes[0, i].imshow(selected_images[i].squeeze().cpu(), cmap='gray', vmax=1.0, vmin=0)
        axes[1, i].imshow(reconstructed[i].squeeze().cpu().detach(), cmap='gray', vmax=1.0, vmin=0)
        axes[0, i].axis('off')
        axes[1, i].axis('off')
    plt.show()

# %%
import torch
import numpy as np
from tqdm import tqdm
from torchvision import transforms
from skimage import io
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE


# Step 5: Show multiple decoded images per cluster

def cluster_and_display_images(latents, labels, images, model, num_samples_per_cluster=10):
    unique_labels = np.unique(labels)
    fig, axes = plt.subplots(len(unique_labels)*2, num_samples_per_cluster, figsize=(num_samples_per_cluster*1.5, len(unique_labels)*2))

    for cluster_idx, cluster_label in enumerate(unique_labels):
        cluster_indices = np.where(labels == cluster_label)[0][:num_samples_per_cluster]
        cluster_images = images[cluster_indices].to(device)
        recon_images, _ = model(cluster_images)

        for i in range(num_samples_per_cluster):
            axes[2 * cluster_idx, i].imshow(cluster_images[i].squeeze().cpu(), cmap='gray', vmin=0, vmax=1.0)
            axes[2 * cluster_idx + 1, i].imshow(recon_images[i].squeeze().cpu().detach(), cmap='gray', vmin=0, vmax=1.0)
            axes[2 * cluster_idx, i].axis('off')
            axes[2 * cluster_idx + 1, i].axis('off')

    plt.tight_layout()
    plt.show()

# %%
latents, labels, images = cluster_latents(ae, train_loader, num_clusters=4)
# Out:
# /tmp/ipykernel_2940993/1666222699.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)

# %%
visualize_clusters(latents, labels, images, ae)

# %%
cluster_and_display_images(latents, labels, images, ae, num_samples_per_cluster=10)
